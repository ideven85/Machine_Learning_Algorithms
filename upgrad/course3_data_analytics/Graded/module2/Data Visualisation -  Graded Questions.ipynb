# %% [markdown]
# ## Data Visualisation - Graded Questions

# %% [markdown]
# `Note` - *This stub file doesn't contain the conceptual questions asked on the platform*

# %% [markdown]
# ### I) Marks Analysis
#
# In the **'Marks.csv'** file, you can find the scores obtained by 200 students in 4 subjects of a standardised test. The different columns - `Score A`, `Score B`, `Score C` and `Score D` indicate the score obtained by a particular student in the respective subjects A, B, C and D.
#
#
#
# Load the dataset to your notebook and answer the following questions

# %%
# Load the necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df1 = pd.read_csv("Marks.csv")
df1.head()
# Out:
#    Score A  Score B  Score C  Score D
# 0    230.1     37.8     69.2     22.1
# 1     44.5     39.3     45.1     10.4
# 2     17.2     45.9     69.3     12.0
# 3    151.5     41.3     58.5     16.5
# 4    180.8     10.8     58.4     17.9

# %% [markdown]
# **Q1)** Load the dataset and plot a histogram for the `Score A` column by keeping the `number of bins to 6`. Which bin range among the following has the highest frequency?
#
# (`Note` - *The bin ranges mentioned in the options are approximate values for the bin ranges that you'll actually get when you plot the histogram*)
#
#     a)0-50
#     b)50-100
#     c)150-200
#     d)200-250*

# %%
# Your code here
sns.histplot(df1["Score A"], bins=6)
# Out:
# <Axes: xlabel='Score A', ylabel='Count'>

# %% [markdown]
# **Q2)** Plot a box plot for the column `Score C` and choose the correct option.
#
#     A - The 25th percentile lies between 20 and 40
#     B - The 75th percentile lies between 40 and 60
#     C - The 25th percentile lies between 0 and 20
#     D - Both B and C*

# %%
# Your code here
sns.boxplot(df1["Score C"])
# Out:
# <Axes: ylabel='Score C'>

# %%
np.quantile(df1["Score C"], q=0.25)
# Out:
# np.float64(12.75)

# %%
df1["Score C"].describe()
# Out:
# count    200.000000
# mean      30.554000
# std       21.778621
# min        0.300000
# 25%       12.750000
# 50%       25.750000
# 75%       45.100000
# max      114.000000
# Name: Score C, dtype: float64

# %% [markdown]
# ### II) Superstore Data
#
# In the `superstore.csv` file, you have the details of orders purchased in an American online retail store. Load the dataset, observe and analyse the different columns and answer the following questions.

# %%
# Load the dataset
df2 = pd.read_csv("superstore.csv")

# %%
df2.head()
# Out:
#          Order ID       Ship Mode    Segment Region       Product ID  \
# 0  CA-2016-152156    Second Class   Consumer  South  FUR-BO-10001798
# 1  CA-2016-152156    Second Class   Consumer  South  FUR-CH-10000454
# 2  CA-2016-138688    Second Class  Corporate   West  OFF-LA-10000240
# 3  US-2015-108966  Standard Class   Consumer  South  FUR-TA-10000577
# 4  US-2015-108966  Standard Class   Consumer  South  OFF-ST-10000760
#
#       Sales  Quantity Discount    Profit
# 0  261.9600         2       0%   41.9136
# 1  731.9400         3       0%  219.5820
# 2   14.6200         2       0%    6.8714
# 3  957.5775         5    0.45% -383.0310
# 4   22.3680         2    0.20%    2.5164

# %% [markdown]
# **Q4)** Plot a pie-chart to find the Ship Mode through which most of the orders are being delivered.
#
#      a)Standard Class
#      b)First Class
#      c)Second Class
#      d)Same Day

# %%
# Your code here
plt.pie(df2["Ship Mode"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 #Your code here
# ----> 2 plt.pie(df2['Ship Mode'])
#
# File /opt/anaconda3/envs/ML_AI/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/ML_AI/lib/python3.12/site-packages/matplotlib/pyplot.py:3797, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3774 @_copy_docstring_and_deprecators(Axes.pie)
#    3775 def pie(
#    3776     x: ArrayLike,
#    (...)
#    3795     data=None,
#    3796 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3797     return gca().pie(
#    3798         x,
#    3799         explode=explode,
#    3800         labels=labels,
#    3801         colors=colors,
#    3802         autopct=autopct,
#    3803         pctdistance=pctdistance,
#    3804         shadow=shadow,
#    3805         labeldistance=labeldistance,
#    3806         startangle=startangle,
#    3807         radius=radius,
#    3808         counterclock=counterclock,
#    3809         wedgeprops=wedgeprops,
#    3810         textprops=textprops,
#    3811         center=center,
#    3812         frame=frame,
#    3813         rotatelabels=rotatelabels,
#    3814         normalize=normalize,
#    3815         hatch=hatch,
#    3816         **({"data": data} if data is not None else {}),
#    3817     )
#
# File /opt/anaconda3/envs/ML_AI/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/ML_AI/lib/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/envs/ML_AI/lib/python3.12/site-packages/matplotlib/axes/_axes.py:3333, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3330 self.set_aspect('equal')
#    3331 # The use of float32 is "historical", but can't be changed without
#    3332 # regenerating the test baselines.
# -> 3333 x = np.asarray(x, np.float32)
#    3334 if x.ndim > 1:
#    3335     raise ValueError("x must be 1D")
#
# File /opt/anaconda3/envs/ML_AI/lib/python3.12/site-packages/pandas/core/series.py:1031, in Series.__array__(self, dtype, copy)
#     981 """
#     982 Return the values as a NumPy array.
#     983
#    (...)
#    1028       dtype='datetime64[ns]')
#    1029 """
#    1030 values = self._values
# -> 1031 arr = np.asarray(values, dtype=dtype)
#    1032 if using_copy_on_write() and astype_is_view(values.dtype, arr.dtype):
#    1033     arr = arr.view()
#
# ValueError: could not convert string to float: 'Second Class'

# %% [markdown]
# **Q5)** Plot a bar chart comparing the average `Discount` across all the `Regions` and report back the `Region` getting the highest average discount
#
# **Note** - You need to clean the `Discount` column first
#
#     a)Central
#     b)South
#     c)West
#     d)East

# %%
# Your code here
