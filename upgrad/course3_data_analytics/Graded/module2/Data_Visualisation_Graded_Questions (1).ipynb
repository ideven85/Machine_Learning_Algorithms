# %% [markdown]
# ## Data Visualisation - Graded Questions

# %% [markdown]
# `Note` - *This stub file doesn't contain the conceptual questions asked on the platform*

# %% [markdown]
# ### I) Marks Analysis
#
# In the **'Marks.csv'** file, you can find the scores obtained by 200 students in 4 subjects of a standardised test. The different columns - `Score A`, `Score B`, `Score C` and `Score D` indicate the score obtained by a particular student in the respective subjects A, B, C and D.
#
#
#
# Load the dataset to your notebook and answer the following questions

# %%
# Load the necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
Path(__name__).resolve().parent.absolute()
# Out:
# PosixPath('/content')

# %%
# from google.colab import drive
# drive.mount('/content/drive')
path = os.path.join(
    "/content/drive/MyDrive/IIITB_ML_AI_Backup/Graded Exercises/Data Visualisation - Graded Questions",
    "Marks.csv",
)

# %%
# !ls /content/drive/
import os

print(os.getcwd())

df = pd.read_csv(path)
# Out:
# MyDrive
# /content

# %%
# Load the dataset
df.head()
# Out:
#    Score A  Score B  Score C  Score D
# 0    230.1     37.8     69.2     22.1
# 1     44.5     39.3     45.1     10.4
# 2     17.2     45.9     69.3     12.0
# 3    151.5     41.3     58.5     16.5
# 4    180.8     10.8     58.4     17.9

# %% [markdown]
# **Q1)** Load the dataset and plot a histogram for the `Score A` column by keeping the `number of bins to 6`. Which bin range among the following has the highest frequency?
#
# (`Note` - *The bin ranges mentioned in the options are approximate values for the bin ranges that you'll actually get when you plot the histogram*)
#
#     a)0-50
#     b)50-100
#     c)150-200
#     d)200-250*

# %%
# Your code here
sns.histplot(df["Score A"], bins=6)
# Out:
# <Axes: xlabel='Score A', ylabel='Count'>

# %% [markdown]
# **Q2)** Plot a box plot for the column `Score C` and choose the correct option.
#
#     A - The 25th percentile lies between 20 and 40
#     B - The 75th percentile lies between 40 and 60
#     C - The 25th percentile lies between 0 and 20
#     D - Both B and C*

# %%
# Your code here
sns.boxplot(df["Score C"])
# Out:
# <Axes: ylabel='Score C'>

# %%
df["Score C"].describe()
# Out:
# count    200.000000
# mean      30.554000
# std       21.778621
# min        0.300000
# 25%       12.750000
# 50%       25.750000
# 75%       45.100000
# max      114.000000
# Name: Score C, dtype: float64

# %% [markdown]
# ### II) Superstore Data
#
# In the `superstore.csv` file, you have the details of orders purchased in an American online retail store. Load the dataset, observe and analyse the different columns and answer the following questions.

# %%
# Load the dataset
df2 = pd.read_csv(
    os.path.join(
        "/content/drive/MyDrive/IIITB_ML_AI_Backup/Graded Exercises/Data Visualisation - Graded Questions",
        "superstore.csv",
    )
)

# %% [markdown]
# **Q4)** Plot a pie-chart to find the Ship Mode through which most of the orders are being delivered.
#
#      a)Standard Class*
#      b)First Class
#      c)Second Class
#      d)Same Day

# %%
df2.head()
# Out:
#          Order ID       Ship Mode    Segment Region       Product ID  \
# 0  CA-2016-152156    Second Class   Consumer  South  FUR-BO-10001798
# 1  CA-2016-152156    Second Class   Consumer  South  FUR-CH-10000454
# 2  CA-2016-138688    Second Class  Corporate   West  OFF-LA-10000240
# 3  US-2015-108966  Standard Class   Consumer  South  FUR-TA-10000577
# 4  US-2015-108966  Standard Class   Consumer  South  OFF-ST-10000760
#
#       Sales  Quantity Discount    Profit
# 0  261.9600         2       0%   41.9136
# 1  731.9400         3       0%  219.5820
# 2   14.6200         2       0%    6.8714
# 3  957.5775         5    0.45% -383.0310
# 4   22.3680         2    0.20%    2.5164

# %%
# Your code here
data = [44, 45, 40, 41, 39]
keys = ["Class 1", "Class 2", "CLass 3", "Class 4", "Class 5"]

# define Seaborn color palette to use
palette_color = sns.color_palette("bright")

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color, autopct="%.0f%%")

# displaying chart
plt.show()

# %%
df2["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
labels = ["Standard Class", "Second Class", "First Class", "Same Day"]
df2["Ship Mode"].value_counts().plot.pie(labels=labels, autopct="%1.1f%%")
plt.legend()
plt.show()

# %% [markdown]
# **Q5)** Plot a bar chart comparing the average `Discount` across all the `Regions` and report back the `Region` getting the highest average discount
#
# **Note** - You need to clean the `Discount` column first
#
#     a)Central*
#     b)South
#     c)West
#     d)East

# %%
# #Your code here
# plt.figure(figsize=(9,7))
# sns.barplot(data=df2,x='Region',y='Discount',hue='Region')

# %%
df2["Discount"].describe()
# Out:
# count     9994
# unique      12
# top         0%
# freq      4798
# Name: Discount, dtype: object

# %%
# df2['Discount'].plot.box()

# %%
# sns.boxplot(data=df2,x='Region',y='Discount')

# %%
df2["Discount"].unique()
# Out:
# array(['0%', '0.45%', '0.20%', '0.80%', '0.30%', '0.50%', '0.70%',
#        '0.60%', '0.32%', '0.10%', '0.40%', '0.15%'], dtype=object)

# %%
df2["Discount"].dtype
# Out:
# dtype('O')

# %%
df2["Discount"] = df2["Discount"].apply(lambda x: float(x.replace("%", "")))

# %%
fig = sns.barplot(data=df2, x="Region", y="Discount", hue="Region")
# fig.annotate()

# %%
df3 = df2[(df2.Profit < 0) & (df2.Sales < 15000)]
sns.jointplot(x="Sales", y="Profit", data=df3)
plt.show()

# %%
sns.barplot(data=df2, x="Segment", y="Sales")
# Out:
# <Axes: xlabel='Segment', ylabel='Sales'>

# %%
sns.barplot(data=df2, x="Segment", y="Sales", estimator=np.mean)
# Out:
# <Axes: xlabel='Segment', ylabel='Sales'>

# %%
# ?sns.barplot
