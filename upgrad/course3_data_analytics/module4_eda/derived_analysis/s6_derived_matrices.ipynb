# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("nas.csv")

# %%
df[:20]
# Out:
#           STUID        State  District Gender       Age  Category  \
# 0   26011001001  Maharashtra         1   Girl  13 years       3.0
# 1   26011001002  Maharashtra         1   Girl  15 years       3.0
# 2   26011001003  Maharashtra         1   Girl  14 years       3.0
# 3   26011001004  Maharashtra         1    Boy  13 years       3.0
# 4   26011001005  Maharashtra         1   Girl  14 years       3.0
# 5   26011001006  Maharashtra         1   Girl  13 years       3.0
# 6   26011001007  Maharashtra         1   Girl  14 years       1.0
# 7   26011001013  Maharashtra         1   Girl       NaN       1.0
# 8   26011001014  Maharashtra         1   Girl       NaN       2.0
# 9   26011001015  Maharashtra         1   Girl  13 years       4.0
# 10  26011001017  Maharashtra         1   Girl  15 years       3.0
# 11  26011001018  Maharashtra         1   Girl  13 years       3.0
# 12  26011001019  Maharashtra         1    Boy  15 years       3.0
# ...

# %%
df.isna().sum()
# Out:
# STUID                   0
# State                   0
# District                0
# Gender                  2
# Age                   232
#                      ...
# Help.in.household      44
# Maths..              4611
# Reading..            4574
# Science..            4657
# Social..             4682
# Length: 64, dtype: int64

# %%
df.describe()
# Out:
#               STUID     District     Category  Same.language      Maths..  \
# count  8.801000e+03  8801.000000  8232.000000    8572.000000  4190.000000
# mean   2.608389e+10     8.255766     2.787293       1.102776    31.601532
# std    4.069188e+07     4.065476     1.146670       0.303684    14.734404
# min    2.601100e+10     1.000000     1.000000       1.000000     0.000000
# 25%    2.604207e+10     4.000000     2.000000       1.000000    22.030000
# 50%    2.609115e+10     9.000000     3.000000       1.000000    28.070000
# 75%    2.612121e+10    12.000000     4.000000       1.000000    36.840000
# max    2.614127e+10    14.000000     4.000000       2.000000    94.740000
#
#          Reading..    Science..     Social..
# count  4227.000000  4144.000000  4119.000000
# mean     55.404436    36.313272    40.502527
# std      23.279043    13.199105    14.479584
# min       0.000000     0.000000     0.000000
# 25%      35.575000    27.270000    30.610000
# ...

# %%
cricket = pd.read_csv("odi-batting.csv")

# %%
cricket.describe()
# Out:
#                Runs         Balls
# count  50284.000000  50284.000000
# mean      24.725141     34.019052
# std       25.783347     30.773306
# min        1.000000      1.000000
# 25%        6.000000     11.000000
# 50%       16.000000     24.000000
# 75%       35.000000     48.000000
# max      200.000000    210.000000

# %%
cricket.head()
# Out:
#        Country            Player  Runs   MatchDate Weekday  \
# 0  Afghanistan  Mohammad Shahzad   118  16-02-2010     Tue
# 1  Afghanistan  Mohammad Shahzad   110  01-09-2009     Tue
# 2  Afghanistan  Mohammad Shahzad   100  16-08-2010     Mon
# 3  Afghanistan  Mohammad Shahzad    82  10-07-2010     Sat
# 4  Afghanistan  Mohammad Shahzad    57  01-07-2010     Thu
#
#                   Ground       Versus  Balls
# 0     Sharjah CA Stadium       Canada    121
# 1             VRA Ground  Netherlands    111
# 2  Cambusdoon New Ground     Scotland     72
# 3            Hazelaarweg  Netherlands    108
# 4    Sportpark Westvliet       Canada     57

# %%
cricket["Centuries"] = cricket["Runs"].apply(lambda x: 1 if x >= 100 else 0)

# %%
cricket
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110  01-09-2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 3      Afghanistan     Mohammad Shahzad    82  10-07-2010     Sat
# 4      Afghanistan     Mohammad Shahzad    57  01-07-2010     Thu
# ...            ...                  ...   ...         ...     ...
# 50279     Zimbabwe        Kevin G Duers     5  10-03-1992     Tue
# 50280     Zimbabwe        Kevin G Duers     2  14-03-1992     Sat
# 50281     Zimbabwe        Ujesh Ranchod     3  03-02-1993     Wed
# 50282     Zimbabwe       Brian V Vitori     3  14-09-2011     Wed
# 50283     Zimbabwe  Waddington Mwayenga     1  29-05-2004     Sat
#
#                       Ground        Versus  Balls  Centuries
# 0         Sharjah CA Stadium        Canada    121          1
# ...

# %%
cricket[cricket["Player"] == "Ricky T Ponting"]["Centuries"].sum()
# Out:
# np.int64(30)

# %%
cricket[cricket["Player"] == "Sachin R Tendulkar"]["Centuries"].sum()
# Out:
# np.int64(48)

# %%
sr = cricket[cricket["Centuries"] == 1]

# %%
sr
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110  01-09-2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 62     Afghanistan      Noor Ali Zadran   114  16-02-2010     Tue
# 87     Afghanistan         Karim Sadiq    114  16-08-2010     Mon
# ...            ...                  ...   ...         ...     ...
# 48682     Zimbabwe     David L Houghton   142  10-10-1987     Sat
# 48737     Zimbabwe       Dion D Ebrahim   121  25-11-2001     Sun
# 49101     Zimbabwe   Charles K Coventry   194  16-08-2009     Sun
# 49208     Zimbabwe        Sean M Ervine   100  24-01-2004     Sat
# 49237     Zimbabwe  Douglas A Marillier   100  05-04-2003     Sat
#
#                              Ground       Versus  Balls  Centuries
# 0                Sharjah CA Stadium       Canada    121          1
# ...

# %%
sr["Strike_Rate"] = sr["Runs"] / sr["Balls"]
# Out:
# /var/folders/1x/76pr210s0kg21gzfc9vtn0x40000gn/T/ipykernel_28227/2210205377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sr['Strike_Rate']=sr['Runs']/sr['Balls']

# %%
sr
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110  01-09-2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 62     Afghanistan      Noor Ali Zadran   114  16-02-2010     Tue
# 87     Afghanistan         Karim Sadiq    114  16-08-2010     Mon
# ...            ...                  ...   ...         ...     ...
# 48682     Zimbabwe     David L Houghton   142  10-10-1987     Sat
# 48737     Zimbabwe       Dion D Ebrahim   121  25-11-2001     Sun
# 49101     Zimbabwe   Charles K Coventry   194  16-08-2009     Sun
# 49208     Zimbabwe        Sean M Ervine   100  24-01-2004     Sat
# 49237     Zimbabwe  Douglas A Marillier   100  05-04-2003     Sat
#
#                              Ground       Versus  Balls  Centuries  \
# 0                Sharjah CA Stadium       Canada    121          1
# ...

# %%
sr[sr["Player"] == "Shayne R Watson"]
# Out:
# Empty DataFrame
# Columns: [Country, Player, Runs, MatchDate, Weekday, Ground, Versus, Balls, Centuries, Strike_Rate]
# Index: []

# %%
sr[sr["Player"] == "Shahid Afridi"]["Strike_Rate"]
# Out:
# 28153    2.066667
# 28154    1.159574
# 28155    1.434211
# 28156    1.173913
# 28157    2.550000
# 28158    2.217391
# Name: Strike_Rate, dtype: float64

# %%
sr.to_csv("centuries.csv")
