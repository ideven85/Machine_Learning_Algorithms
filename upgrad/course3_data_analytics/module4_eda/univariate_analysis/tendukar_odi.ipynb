# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/tendulkar_ODI.csv")

# %%
df[df["Runs"] == "8*"]

# %% [markdown]
# The variables 'Runs' and 'X4s' respectively represent the number of runs scored and number of 4s hit by him in each match. These are two ordered categorical variables you'll analyse in this exercise.
#
#
# 'Runs', which should ideally be a numeric variable, contains some entries such as DNB (Did Not Bat), 8* (Not out at 8 runs) etc. You'll need to clean these quality issues.
#
#
# Similarly, in 'X4s', there are some missing entries represented by "-". You will need to clean them as well.
#
#
# You have seen how to conduct univariate analysis on categorical variables. Next, you will learn to conduct univariate analysis on quantitative (or numeric) variables.

# %%
df["Runs"].describe()

# %%
df.dtypes

# %%
df[df["Runs"] == "DNB"]["Runs"]

# %%
df[df["4s"] == "-"]["4s"]

# %%
df["Runs"].loc[8]

# %%
# print(df["4s"][:20])

# %%
df = df[~(df["Runs"] == "DNB")]

# %%
df = df[~(df["Runs"] == "TDNB")]

# %%
df.head()

# %%
# df[:15]

# %%
def clean_runs(val):
    return int(val[:-1]) if val[-1] == "*" else int(val)

# %%
df[df["Runs"] == "DNB"]

# %%
df["Runs"] = df["Runs"].apply(clean_runs)

# %%
df["Runs"].describe()

# %%
sns.boxplot(df, y="Runs")
plt.show()

# %%
df[df["4s"] == "-"]

# %%
df["4s"] = df["4s"].astype("int32")

# %%
df.head()

# %%
df[:10]

# %%
# sns.barplot(x=df['Runs'],y=df)
df["Runs"].plot.box()
plt.show()

# %%
print(df[df["Runs"] <= 10]["Runs"].count())
print(df[(df["Runs"] > 10) & (df["Runs"] <= 20)]["Runs"].count())
print(df[(df["Runs"] > 20) & (df["Runs"] <= 30)]["Runs"].count())
print(df[(df["Runs"] > 30) & (df["Runs"] <= 40)]["Runs"].count())

# %%
df["4s"].value_counts()

# %%
sns.histplot(df["4s"], bins=[0, 4, 8, 12, 16, 20, 24, 48])
plt.show()

# %%
sns.histplot(df["Runs"], bins=[0, 10, 20, 30, 40, 50])
