# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# print()

# %%
from ucimlrepo import fetch_ucirepo

online_news_popularity = fetch_ucirepo(id=332)
X = online_news_popularity.data.features
y = online_news_popularity.data.targets

# metadata
online_news_popularity.metadata.variable_info

# variable information

# %%
type(online_news_popularity)
# Out:
# ucimlrepo.dotdict.dotdict

# %%
for key, value in online_news_popularity.data.items():
    print(key, type(value))
# Out:
# ids <class 'pandas.core.frame.DataFrame'>
# features <class 'pandas.core.frame.DataFrame'>
# targets <class 'pandas.core.frame.DataFrame'>
# original <class 'pandas.core.frame.DataFrame'>
# headers <class 'pandas.core.indexes.base.Index'>

# %%
online_news_popularity.data.features[:20]
# Out:
#     n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0             12.0             219.0         0.663594               1.0
# 1              9.0             255.0         0.604743               1.0
# 2              9.0             211.0         0.575130               1.0
# 3              9.0             531.0         0.503788               1.0
# 4             13.0            1072.0         0.415646               1.0
# 5             10.0             370.0         0.559889               1.0
# 6              8.0             960.0         0.418163               1.0
# 7             12.0             989.0         0.433574               1.0
# 8             11.0              97.0         0.670103               1.0
# 9             10.0             231.0         0.636364               1.0
# 10             9.0            1248.0         0.490050               1.0
# 11            10.0             187.0         0.666667               1.0
# ...

# %%
online_news_popularity.data.targets[:20]
# Out:
#     shares
# 0      593
# 1      711
# 2     1500
# 3     1200
# 4      505
# 5      855
# 6      556
# 7      891
# 8     3600
# 9      710
# 10    2200
# 11    1900
# 12     823
# 13   10000
# 14     761
# 15    1600
# 16   13600
# 17    3100
# 18    5700
# 19   17100

# %%
headers = online_news_popularity.data.headers

# %%
headers
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
# ...

# %%
print(online_news_popularity.variables["name"])
# Out:
# 0                               url
# 1                         timedelta
# 2                    n_tokens_title
# 3                  n_tokens_content
# 4                   n_unique_tokens
#                   ...
# 56               title_subjectivity
# 57         title_sentiment_polarity
# 58           abs_title_subjectivity
# 59     abs_title_sentiment_polarity
# 60                           shares
# Name: name, Length: 61, dtype: object

# %%
popularity = pd.read_csv("../../data/popularity.csv")

# %%
popularity
# Out:
#                                                      url   timedelta  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2      http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3      http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
# ...                                                  ...         ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...         8.0
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...         8.0
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...         8.0
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/         8.0
# 39643  http://mashable.com/2014/12/27/youtube-channel...         8.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 0                 12.0              219.0          0.663594
# ...

# %%
popularity[" num_keywords"].mode()
# Out:
# 0    7.0
# Name:  num_keywords, dtype: float64

# %%
np.mean(popularity[" shares"])
# Out:
# 3395.3801836343455

# %%
np.median(popularity[" shares"])
# Out:
# 1400.0

# %%
# sns.boxplot(popularity,y=' shares',hue='url')
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x112ab9370>>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ML_AI/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
