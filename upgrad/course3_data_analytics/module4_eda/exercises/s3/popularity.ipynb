# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
df = pd.read_csv("../../data/OnlineNewsPopularity.csv")

# %%
df["weekday_is_monday"].describe()
# Out:
# count    39644.000000
# mean         0.168020
# std          0.373889
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: weekday_is_monday, dtype: float64

# %%
df.columns
# Out:
# Index(['url', 'timedelta', 'n_tokens_title', 'n_tokens_content',
#        'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens',
#        'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos',
#        'average_token_length', 'num_keywords', 'data_channel_is_lifestyle',
#        'data_channel_is_entertainment', 'data_channel_is_bus',
#        'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min',
#        'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg',
#        'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares',
#        'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday',
#        'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
#        'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity',
# ...

# %%
df["weekday_is_monday"].describe()
# Out:
# count    39644.000000
# mean         0.168020
# std          0.373889
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: weekday_is_monday, dtype: float64

# %%
# df['data_channel_is_lifestyle'::' shares']

# %%
df[" data_channel_is_lifestyle"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/ML_AI/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' data_channel_is_lifestyle'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ...

# %%
# df[' weekday_is_monday':' weekday_is_friday']

# %%
# df[' weekday_is_friday']

# %%
# df[' weekday_is_monday'].std()

# %%
# df[' weekday_is_tuesday'].std()

# %%
total_weekdays_sum = 6601 + 7340 + 7435 + 7267 + 5701

# %%
total_weekdays = 39465 * 5 - 1

# %%
total_weekdays_sum / total_weekdays
# Out:
# 0.17404877257708135

# %%
sns.boxplot(y=df["weekday_is_monday"])
plt.show()

# %%
plt.boxplot(df[" weekday_is_monday"])

# %%
df[" weekday_is_monday"].describe()

# %%
df[" weekday_is_monday"].mean()

# %%
df[" weekday_is_tuesday"].describe()

# %%
df[" weekday_is_tuesday"].mean()

# %%
df[" weekday_is_wednesday"].describe()

# %%
df[" weekday_is_wednesday"].mean()

# %%
df[" weekday_is_thursday"].describe()

# %%
df[" weekday_is_thursday"].mean()

# %%
df[" weekday_is_friday"].describe()

# %%
df[" weekday_is_friday"].mean()

# %%
# sns.boxplot(df['weekday_is_tuesday'])
# plt.show()

# %%
# sns.boxplot(df[' weekday_is_wednesday'])
# plt.show()

# %%
# sns.boxplot(df[' weekday_is_thursday'])
# plt.show()

# %%
# sns.boxplot(df[' weekday_is_friday'])
# plt.show()

# %%
# df[:-1]

# %%
# df[df[' shares'][' shares']]==2500

# %%
2500 in df["shares"]
# Out:
# True

# %%
x = df[df["shares"] == 2500]

# %%
x = df["data_channel_is_lifestyle"].sum()

# %%
x[" data_channel_is_entertainment"].sum()

# %%
x[" data_channel_is_lifestyle"].sum()

# %%
x[" data_channel_is_socmed"].sum()

# %%
x[" data_channel_is_tech"].sum()

# %%
x[" data_channel_is_world"].sum()

# %%
df[" shares"].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df[' shares'].describe()
#
# NameError: name 'df' is not defined

# %%
df["shares"].plot.box()
# Out:
# <Axes: >

# %%
sns.boxplot(df[" shares"])
plt.show()

# %%
np.percentile(df[" shares"], 60)

# %%
np.percentile(df[" shares"], 70)

# %%
np.percentile(df[" shares"], 75)

# %%
np.percentile(df[" shares"], 70)

# %%
np.percentile(df[" shares"], 72)

# %%
sns.boxplot(df[[" shares", " data_channel_is_tech"]])

# %%
sns.boxplot(df[" data_channel_is_tech"])

# %%
sns.histplot(df[" data_channel_is_tech"])
plt.show()

# %%
sns.displot(x=df[" shares"], y=df[" data_channel_is_socmed"])

# %%
sns.boxplot(df[[" data_channel_is_socmed", " shares"]])

# %%
np.percentile(df[" shares"], 72)

# %%
np.percentile(df[" data_channel_is_socmed"], 72)

# %%
df["shares"].plot.box()
# Out:
# <Axes: >

# %%
sns.boxplot(df["shares"])
# Out:
# <Axes: ylabel='shares'>

# %%
df["shares"].describe()
# Out:
# count     39644.000000
# mean       3395.380184
# std       11626.950749
# min           1.000000
# 25%         946.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name: shares, dtype: float64

# %%
IQR = 2800 - 946

# %%
IQR
# Out:
# 1854

# %%
sns.histplot(df["shares"], bins=[0, 2000, 4000, 6000, 8000, 10000, 40000])
# Out:
# <Axes: xlabel='shares', ylabel='Count'>

# %%
df[df["shares"] < np.percentile(df["shares"], 75)].shape[0] / 39644
# Out:
# 0.7480324891534659

# %%
df["shares"].count()
# Out:
# 39644

# %%
df[(df["shares"] < 945)].shape[0]
# Out:
# 9880

# %%
sns.scatterplot(df, x="shares", y="is_weekend")
plt.show()

# %%
df.head()
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                  0.815385        4.0             2.0       1.0  ...
# ...

# %%
df.columns
# Out:
# Index(['url', 'timedelta', 'n_tokens_title', 'n_tokens_content',
#        'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens',
#        'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos',
#        'average_token_length', 'num_keywords', 'data_channel_is_lifestyle',
#        'data_channel_is_entertainment', 'data_channel_is_bus',
#        'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min',
#        'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg',
#        'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares',
#        'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday',
#        'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
#        'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity',
# ...

# %%
sns.boxplot(y=df["shares"], x=df["weekday_is_saturday"] + df["weekday_is_sunday"])
# Out:
# <Axes: xlabel='None', ylabel='shares'>

# %%
saturday = (df["weekday_is_saturday"] + df["shares"]).sum()
sunday = (df["weekday_is_sunday"] + df["shares"]).sum()

# %%
weekend = df["is_weekend"].add(df["shares"])

# %%
weekend
# Out:
# 0         593.0
# 1         711.0
# 2        1500.0
# 3        1200.0
# 4         505.0
#           ...
# 39639    1800.0
# 39640    1900.0
# 39641    1900.0
# 39642    1100.0
# 39643    1300.0
# Length: 39644, dtype: float64

# %%
print(type(weekend), type(df["shares"]))
# Out:
# <class 'pandas.core.series.Series'> <class 'pandas.core.series.Series'>

# %%
# df['weekend']=weekend
# sns.boxplot(df,x='weekend',y='shares')
# plt.show()

# %%
saturday
# Out:
# 134608905.0

# %%
sunday
# Out:
# 134609189.0

# %%
(saturday + sunday) / 2
# Out:
# 134609047.0

# %%
weekend
# Out:
# 134611642.0

# %%
weekend.mean()
# Out:
# 134611642.0

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 (saturday+sunday).average()
#
# AttributeError: 'numpy.float64' object has no attribute 'average'

# %%
weekend
# Out:
# 0         593.0
# 1         711.0
# 2        1500.0
# 3        1200.0
# 4         505.0
#           ...
# 39639    1800.0
# 39640    1900.0
# 39641    1900.0
# 39642    1100.0
# 39643    1300.0
# Length: 39644, dtype: float64

# %%
df["monday"] = df["weekday_is_monday"].add(df["shares"])

# %%
df["monday"]
# Out:
# 0         594.0
# 1         712.0
# 2        1501.0
# 3        1201.0
# 4         506.0
#           ...
# 39639    1800.0
# 39640    1900.0
# 39641    1900.0
# 39642    1100.0
# 39643    1300.0
# Name: monday, Length: 39644, dtype: float64

# %%
# sns.histplot(df,x='monday',y='weekend')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 2
#       1 sns.histplot(df,x='monday',y='weekend')
# ----> 2 plt.show()
#
# File /opt/anaconda3/envs/ML_AI/lib/python3.12/site-packages/matplotlib/pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)
#     611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# File /opt/anaconda3/envs/ML_AI/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
# ...
