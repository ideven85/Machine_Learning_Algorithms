# %% [markdown]
# # Order Delivery Time Prediction

# %% [markdown]
# ## Objectives
# The objective of this assignment is to build a regression model that predicts the delivery time for orders placed through Porter. The model will use various features such as the items ordered, the restaurant location, the order protocol, and the availability of delivery partners.
#
# The key goals are:
# - Predict the delivery time for an order based on multiple input features
# - Improve delivery time predictions to optimiae operational efficiency
# - Understand the key factors influencing delivery time to enhance the model's accuracy

# %% [markdown]
# ## Data Pipeline
# The data pipeline for this assignment will involve the following steps:
# 1. **Data Loading**
# 2. **Data Preprocessing and Feature Engineering**
# 3. **Exploratory Data Analysis**
# 4. **Model Building**
# 5. **Model Inference**

# %% [markdown]
# ## Data Understanding
# The dataset contains information on orders placed through Porter, with the following columns:
#
# | Field                     | Description                                                                                 |
# |---------------------------|---------------------------------------------------------------------------------------------|
# | market_id                 | Integer ID representing the market where the restaurant is located.                         |
# | created_at                | Timestamp when the order was placed.                                                        |
# | actual_delivery_time      | Timestamp when the order was delivered.                                                     |
# | store_primary_category    | Category of the restaurant (e.g., fast food, dine-in).                                      |
# | order_protocol            | Integer representing how the order was placed (e.g., via Porter, call to restaurant, etc.). |
# | total_items               | Total number of items in the order.                                                         |
# | subtotal                  | Final price of the order.                                                                   |
# | num_distinct_items        | Number of distinct items in the order.                                                      |
# | min_item_price            | Price of the cheapest item in the order.                                                    |
# | max_item_price            | Price of the most expensive item in the order.                                              |
# | total_onshift_dashers     | Number of delivery partners on duty when the order was placed.                              |
# | total_busy_dashers        | Number of delivery partners already occupied with other orders.                             |
# | total_outstanding_orders  | Number of orders pending fulfillment at the time of the order.                              |
# | distance                  | Total distance from the restaurant to the customer.                                         |

# %% [markdown]
# ## **Importing Necessary Libraries**

# %%
# Import essential libraries for data manipulation and analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## **1. Loading the data**
# Load 'porter_data_1.csv' as a DataFrame

# %%
# Importing the file porter_data_1.csv
df = pd.read_csv("porter_data_1.csv")

# %%
df.head()
# Out:
#    market_id           created_at actual_delivery_time  \
# 0        1.0  2015-02-06 22:24:17  2015-02-06 23:11:17
# 1        2.0  2015-02-10 21:49:25  2015-02-10 22:33:25
# 2        2.0  2015-02-16 00:11:35  2015-02-16 01:06:35
# 3        1.0  2015-02-12 03:36:46  2015-02-12 04:35:46
# 4        1.0  2015-01-27 02:12:36  2015-01-27 02:58:36
#
#    store_primary_category  order_protocol  total_items  subtotal  \
# 0                       4             1.0            4      3441
# 1                      46             2.0            1      1900
# 2                      36             3.0            4      4771
# 3                      38             1.0            1      1525
# 4                      38             1.0            2      3620
#
#    num_distinct_items  min_item_price  max_item_price  total_onshift_dashers  \
# 0                   4             557            1239                   33.0
# 1                   1            1400            1400                    1.0
# 2                   3             820            1604                    8.0
# 3                   1            1525            1525                    5.0
# 4                   2            1425            2195                    5.0
#
#    total_busy_dashers  total_outstanding_orders  distance
# 0                14.0                      21.0     34.44
# 1                 2.0                       2.0     27.60
# 2                 6.0                      18.0     11.56
# 3                 6.0                       8.0     31.80
# 4                 5.0                       7.0      8.20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175777 entries, 0 to 175776
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   market_id                 175777 non-null  float64
#  1   created_at                175777 non-null  object
#  2   actual_delivery_time      175777 non-null  object
#  3   store_primary_category    175777 non-null  int64
#  4   order_protocol            175777 non-null  float64
#  5   total_items               175777 non-null  int64
#  6   subtotal                  175777 non-null  int64
#  7   num_distinct_items        175777 non-null  int64
#  8   min_item_price            175777 non-null  int64
#  9   max_item_price            175777 non-null  int64
#  10  total_onshift_dashers     175777 non-null  float64
#  11  total_busy_dashers        175777 non-null  float64
#  12  total_outstanding_orders  175777 non-null  float64
#  13  distance                  175777 non-null  float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 18.8+ MB

# %% [markdown]
# ## **2. Data Preprocessing and Feature Engineering** <font color = red>[15 marks]</font> <br>

# %% [markdown]
# #### **2.1 Fixing the Datatypes**  <font color = red>[5 marks]</font> <br>
# The current timestamps are in object format and need conversion to datetime format for easier handling and intended functionality

# %% [markdown]
# ##### **2.1.1** <font color = red>[2 marks]</font> <br>
# Convert date and time fields to appropriate data type

# %%
# Convert 'created_at' and 'actual_delivery_time' columns to datetime format
df["created_at"] = pd.to_datetime(df["created_at"])
df["actual_delivery_time"] = pd.to_datetime(df["actual_delivery_time"])

# %% [markdown]
# ##### **2.1.2**  <font color = red>[3 marks]</font> <br>
# Convert categorical fields to appropriate data type

# %%
# Convert categorical features to category type
var_names = ["market_id", "store_primary_category", "order_protocol"]
for var in var_names:
    df[var] = df[var].astype("category")

# %%
df1 = df.copy()

# %% [markdown]
# #### **2.2 Feature Engineering** <font color = red>[5 marks]</font> <br>
# Calculate the time taken to execute the delivery as well as extract the hour and day at which the order was placed

# %% [markdown]
# ##### **2.2.1** <font color = red>[2 marks]</font> <br>
# Calculate the time taken using the features `actual_delivery_time` and `created_at`

# %%
# Calculate time taken in minutes
(df["actual_delivery_time"] - df["created_at"]).head()
# Out:
# 0   0 days 00:47:00
# 1   0 days 00:44:00
# 2   0 days 00:55:00
# 3   0 days 00:59:00
# 4   0 days 00:46:00
# dtype: timedelta64[ns]

# %%
df["time_taken"] = (df["actual_delivery_time"] - df["created_at"]) / pd.Timedelta(
    minutes=1
)

# %% [markdown]
# ##### **2.2.2** <font color = red>[3 marks]</font> <br>
# Extract the hour at which the order was placed and which day of the week it was. Drop the unnecessary columns.

# %%
# Extract the hour and day of week from the 'created_at' timestamp
df["pickup_hour"] = df["created_at"].dt.hour
df["day_of_week"] = df["created_at"].dt.day_name()

# Create a categorical feature 'isWeekend'
df["isWeekend"] = df["day_of_week"].apply(
    lambda x: 1 if x == "Saturday" or x == "Sunday" else 0
)
df.drop("day_of_week", axis=1, inplace=True)
df["pickup_hour"] = df["pickup_hour"].astype("category")
df["isWeekend"] = df["isWeekend"].astype("category")

# %%
df["num_distinct_items"] = df["num_distinct_items"].astype("category")

# %%
df1 = df.copy()

# %%
# Drop unnecessary columns
df.drop("actual_delivery_time", axis=1, inplace=True)
df.drop("created_at", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175777 entries, 0 to 175776
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   market_id                 175777 non-null  category
#  1   store_primary_category    175777 non-null  category
#  2   order_protocol            175777 non-null  category
#  3   total_items               175777 non-null  int64
#  4   subtotal                  175777 non-null  int64
#  5   num_distinct_items        175777 non-null  category
#  6   min_item_price            175777 non-null  int64
#  7   max_item_price            175777 non-null  int64
#  8   total_onshift_dashers     175777 non-null  float64
#  9   total_busy_dashers        175777 non-null  float64
#  10  total_outstanding_orders  175777 non-null  float64
#  11  distance                  175777 non-null  float64
#  12  time_taken                175777 non-null  float64
#  13  pickup_hour               175777 non-null  category
#  14  isWeekend                 175777 non-null  category
# dtypes: category(6), float64(5), int64(4)
# memory usage: 13.1 MB

# %% [markdown]
# #### **2.3 Creating training and validation sets** <font color = red>[5 marks]</font> <br>

# %% [markdown]
# ##### **2.3.1** <font color = red>[2 marks]</font> <br>
#  Define target and input features

# %%
# Define target variable (y) and features (X)
target_variable = "time_taken"
feature_columns = [col for col in df.columns if col != target_variable]
X = df[feature_columns]
y = df[target_variable]

# %%
X.head()
# Out:
#   market_id store_primary_category order_protocol  total_items  subtotal  \
# 0       1.0                      4            1.0            4      3441
# 1       2.0                     46            2.0            1      1900
# 2       2.0                     36            3.0            4      4771
# 3       1.0                     38            1.0            1      1525
# 4       1.0                     38            1.0            2      3620
#
#   num_distinct_items  min_item_price  max_item_price  total_onshift_dashers  \
# 0                  4             557            1239                   33.0
# 1                  1            1400            1400                    1.0
# 2                  3             820            1604                    8.0
# 3                  1            1525            1525                    5.0
# 4                  2            1425            2195                    5.0
#
#    total_busy_dashers  total_outstanding_orders  distance pickup_hour  \
# 0                14.0                      21.0     34.44          22
# 1                 2.0                       2.0     27.60          21
# 2                 6.0                      18.0     11.56           0
# 3                 6.0                       8.0     31.80           3
# 4                 5.0                       7.0      8.20           2
#
#   isWeekend
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
y.head()
# Out:
# 0    47.0
# 1    44.0
# 2    55.0
# 3    59.0
# 4    46.0
# Name: time_taken, dtype: float64

# %% [markdown]
# ##### **2.3.2** <font color = red>[3 marks]</font> <br>
#  Split the data into training and test sets

# %%
# Split data into training and testing sets
from sklearn.model_selection import train_test_split

# %%
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.8, test_size=0.2, random_state=0
)

# %%
df_train = X_train.copy()
df_train["time_taken"] = y_train
df_test = X_test.copy()
df_test["time_taken"] = y_test

# %%
df_train.head()
# Out:
#        market_id store_primary_category order_protocol  total_items  subtotal  \
# 143786       1.0                      4            3.0            3      2495
# 165941       2.0                     46            5.0            2      1074
# 53920        4.0                     72            1.0            3      2775
# 150506       2.0                     20            5.0            2      1645
# 69767        4.0                     39            5.0            3      2425
#
#        num_distinct_items  min_item_price  max_item_price  \
# 143786                  3             450            1450
# 165941                  2             275             799
# 53920                   2             925             925
# 150506                  2             695             950
# 69767                   3             475             975
#
#         total_onshift_dashers  total_busy_dashers  total_outstanding_orders  \
# 143786                   18.0                18.0                      24.0
# 165941                   36.0                35.0                      49.0
# 53920                    14.0                 9.0                      11.0
# 150506                   85.0               112.0                     100.0
# 69767                   100.0                78.0                     136.0
#
#         distance pickup_hour isWeekend  time_taken
# 143786     16.40          19         1        44.0
# 165941     16.36          19         0        35.0
# 53920      30.00           2         0        49.0
# 150506     34.52           2         0        39.0
# 69767      10.88           2         1        43.0

# %% [markdown]
# ## **3. Exploratory Data Analysis on Training Data** <font color = red>[20 marks]</font> <br>
# 1. Analyzing the correlation between variables to identify patterns and relationships
# 2. Identifying and addressing outliers to ensure the integrity of the analysis
# 3. Exploring the relationships between variables and examining the distribution of the data for better insights

# %% [markdown]
# #### **3.1 Feature Distributions** <font color = red> [7 marks]</font> <br>

# %%
# Define numerical and categorical columns for easy EDA and data manipulation
def categorize(df, columns):
    """
    Categorize columns as numeric or category
    """
    numerical_variables = []
    categorical_variables = []
    for col in columns:
        # print(df[col].dtype)
        if df[col].dtype in ("int64", "float64"):

            numerical_variables.append(col)
        else:
            categorical_variables.append(col)
    return numerical_variables, categorical_variables


numeric_vars, categorical_vars = categorize(X_train, X_train.columns.tolist())
print("Numerical variables:", numeric_vars, "\n\n")
print("Categorical variables:", categorical_vars)
# Out:
# Numerical variables: ['total_items', 'subtotal', 'min_item_price', 'max_item_price', 'total_onshift_dashers', 'total_busy_dashers', 'total_outstanding_orders', 'distance']
#
#
# Categorical variables: ['market_id', 'store_primary_category', 'order_protocol', 'num_distinct_items', 'pickup_hour', 'isWeekend']

# %%
df.to_excel("porter_proper.xlsx")

# %% [markdown]
# ##### **3.1.1** <font color = red>[3 marks]</font> <br>
# Plot distributions for numerical columns in the training set to understand their spread and any skewness

# %%
# Plot distributions for all numerical columns

# %%
for var in numeric_vars:
    sns.histplot(X_train[var], kde=True, color="g", bins=30)
    plt.show()

# %% [markdown]
# f##### **3.1.2** <font color = red>[2 marks]</font> <br>
# Check the distribution of categorical features

# %%
# Distribution of categorical columns
plt.style.use("default")

# %%
# Plotting categorical variables
# todo redo with subplots
plt.figure(figsize=(20, 8))
for var in categorical_vars:
    X_train[var].value_counts().plot.bar()
    plt.xlabel(var)
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# ##### **3.1.3** <font color = red>[2 mark]</font> <br>
# Visualise the distribution of the target variable to understand its spread and any skewness

# %%
# Distribution of time_taken
sns.histplot(y_train, kde=True)
plt.show()

# %%
plt.style.use("default")

# Create pairplot with proper features
plt.figure(figsize=(20, 10))

for i, var in enumerate(numeric_vars, 1):
    plt.subplot(3, 3, i)
    sns.regplot(x=X_train[var], y=y_train)
    plt.xlabel(var)
    plt.ylabel("time_taken")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 10))
for i, var in enumerate(categorical_vars, 1):
    plt.subplot(3, 2, i)

    sns.boxplot(x=X_train[var], y=y_train)
    plt.xlabel(f"{var}")
plt.tight_layout()
plt.show()

# %%
# Show the distribution of time_taken for different hours
plt.figure(figsize=(12, 10))
sns.barplot(x=X_train["pickup_hour"], y=y_train)
plt.show()

# %% [markdown]
# #### **3.3 Correlation Analysis** <font color = red>[5 marks]</font> <br>
# Check correlations between numerical features to identify which variables are strongly related to `time_taken`

# %% [markdown]
# ##### **3.3.1** <font color = red>[3 marks]</font> <br>
# Plot a heatmap to display correlations

# %%
# Plot the heatmap of the correlation matrix

plt.figure(figsize=(12, 10))

X_copy = X_train.copy()
X_copy["time_taken"] = y_train
# Calculate the correlation matrix
corr_matrix = X_copy.corr()

# Plot the heatmap

sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Create correlation matrix
corr_matrix
# Out:
#                           market_id  store_primary_category  order_protocol  \
# market_id                  1.000000                0.033374       -0.013555
# store_primary_category     0.033374                1.000000        0.090729
# order_protocol            -0.013555                0.090729        1.000000
# total_items                0.002963               -0.006025        0.007857
# subtotal                   0.000422                0.040288       -0.052668
# num_distinct_items         0.016041                0.001712       -0.023119
# min_item_price            -0.010062                0.016755       -0.044172
# max_item_price            -0.007367                0.006043       -0.091294
# total_onshift_dashers      0.073178                0.082543        0.147366
# total_busy_dashers         0.064063                0.083024        0.151533
# total_outstanding_orders   0.067378                0.081552        0.135817
# distance                   0.017131                0.000691       -0.009327
# pickup_hour               -0.009478               -0.034552        0.012112
# isWeekend                  0.002113               -0.014958        0.000816
# time_taken                -0.071833                0.027116       -0.138101
#
#                           total_items  subtotal  num_distinct_items  \
# market_id                    0.002963  0.000422            0.016041
# store_primary_category      -0.006025  0.040288            0.001712
# order_protocol               0.007857 -0.052668           -0.023119
# total_items                  1.000000  0.544752            0.746118
# subtotal                     0.544752  1.000000            0.680913
# num_distinct_items           0.746118  0.680913            1.000000
# min_item_price              -0.382160  0.039562           -0.445130
# max_item_price              -0.054731  0.508340            0.045881
# total_onshift_dashers        0.032794  0.132075            0.068047
# total_busy_dashers           0.029981  0.127398            0.063219
# total_outstanding_orders     0.035345  0.131227            0.070125
# distance                     0.006169  0.037923            0.024749
# pickup_hour                 -0.070795 -0.190449           -0.119158
# isWeekend                    0.027473  0.046404            0.043365
# time_taken                   0.220410  0.412612            0.312259
#
#                           min_item_price  max_item_price  \
# market_id                      -0.010062       -0.007367
# store_primary_category          0.016755        0.006043
# order_protocol                 -0.044172       -0.091294
# total_items                    -0.382160       -0.054731
# subtotal                        0.039562        0.508340
# num_distinct_items             -0.445130        0.045881
# min_item_price                  1.000000        0.543312
# max_item_price                  0.543312        1.000000
# total_onshift_dashers           0.040736        0.133460
# total_busy_dashers              0.042268        0.131740
# total_outstanding_orders        0.039796        0.131177
# distance                        0.004001        0.028322
# pickup_hour                    -0.050031       -0.188643
# isWeekend                       0.001209        0.044769
# time_taken                      0.022503        0.254330
#
#                           total_onshift_dashers  total_busy_dashers  \
# market_id                              0.073178            0.064063
# store_primary_category                 0.082543            0.083024
# order_protocol                         0.147366            0.151533
# total_items                            0.032794            0.029981
# subtotal                               0.132075            0.127398
# num_distinct_items                     0.068047            0.063219
# min_item_price                         0.040736            0.042268
# max_item_price                         0.133460            0.131740
# total_onshift_dashers                  1.000000            0.943861
# total_busy_dashers                     0.943861            1.000000
# total_outstanding_orders               0.936073            0.932754
# distance                               0.047114            0.045742
# pickup_hour                           -0.374447           -0.350339
# isWeekend                              0.089715            0.108085
# time_taken                             0.172595            0.207634
#
#                           total_outstanding_orders  distance  pickup_hour  \
# market_id                                 0.067378  0.017131    -0.009478
# store_primary_category                    0.081552  0.000691    -0.034552
# order_protocol                            0.135817 -0.009327     0.012112
# total_items                               0.035345  0.006169    -0.070795
# subtotal                                  0.131227  0.037923    -0.190449
# num_distinct_items                        0.070125  0.024749    -0.119158
# min_item_price                            0.039796  0.004001    -0.050031
# max_item_price                            0.131177  0.028322    -0.188643
# total_onshift_dashers                     0.936073  0.047114    -0.374447
# total_busy_dashers                        0.932754  0.045742    -0.350339
# total_outstanding_orders                  1.000000  0.041473    -0.361922
# distance                                  0.041473  1.000000    -0.025687
# pickup_hour                              -0.361922 -0.025687     1.000000
# isWeekend                                 0.115212  0.009579     0.001012
# time_taken                                0.386869  0.460987    -0.346298
#
#                           isWeekend  time_taken
# market_id                  0.002113   -0.071833
# store_primary_category    -0.014958    0.027116
# order_protocol             0.000816   -0.138101
# total_items                0.027473    0.220410
# subtotal                   0.046404    0.412612
# num_distinct_items         0.043365    0.312259
# min_item_price             0.001209    0.022503
# max_item_price             0.044769    0.254330
# total_onshift_dashers      0.089715    0.172595
# total_busy_dashers         0.108085    0.207634
# total_outstanding_orders   0.115212    0.386869
# distance                   0.009579    0.460987
# pickup_hour                0.001012   -0.346298
# isWeekend                  1.000000    0.135781
# time_taken                 0.135781    1.000000

# %%
# Drop 3-5 weakly correlated columns from training dataset
X_train_copy = X_train.copy()
X_train.drop(
    ["store_primary_category", "market_id", "min_item_price"],
    axis=1,
    inplace=True,
)
X_test.drop(
    ["store_primary_category", "market_id", "min_item_price"],
    axis=1,
    inplace=True,
)

# %%
df_train.drop(
    ["store_primary_category", "market_id", "min_item_price"], axis=1, inplace=True
)
df_test.drop(
    ["store_primary_category", "market_id", "min_item_price"], axis=1, inplace=True
)

# %%
X_train.head()
# Out:
#        order_protocol  total_items  subtotal num_distinct_items  \
# 143786            3.0     0.004878  0.110889                  3
# 165941            5.0     0.002439  0.047733                  2
# 53920             1.0     0.004878  0.123333                  2
# 150506            5.0     0.002439  0.073111                  2
# 69767             5.0     0.004878  0.107778                  3
#
#         max_item_price  total_onshift_dashers  total_busy_dashers  \
# 143786        0.098639               0.127168            0.144654
# 165941        0.054354               0.231214            0.251572
# 53920         0.062925               0.104046            0.088050
# 150506        0.064626               0.514451            0.735849
# 69767         0.066327               0.601156            0.522013
#
#         total_outstanding_orders  distance pickup_hour isWeekend
# 143786                  0.103093  0.196360          19         1
# 165941                  0.189003  0.195881          19         0
# 53920                   0.058419  0.359195           2         0
# 150506                  0.364261  0.413314           2         0
# 69767                   0.487973  0.130268           2         1

# %% [markdown]
# #### **3.4 Handling the Outliers** <font color = red>[5 marks]</font> <br>

# %% [markdown]
# ##### **3.4.1** <font color = red>[2 marks]</font> <br>
# Visualise potential outliers for the target variable and other numerical features using boxplots

# %%
# Boxplot for time_taken
sns.boxplot(y=y_train)
plt.show()

# %%
y_train = y_train[y_train <= 70]

X_train = X_train.loc[y_train.index]

print("New X_train shape:", X_train.shape)
print("New y_train shape:", y_train.shape)
# Out:
# New X_train shape: (138944, 11)
# New y_train shape: (138944,)

# %% [markdown]
# ##### **3.4.2** <font color = red>[3 marks]</font> <br>
# Handle outliers present in all columns

# %%
def outlier_analysis(df, columns):
    # print(columns)
    outlier_summary = {}
    for col in columns:
        # print(col)
        if df[col].dtype not in ("float64", "int64", "int32"):
            continue
        min_value = df[col].min()
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        mean = df[col].mean()
        median = df[col].median()
        mode = df[col].mode()[0]
        maximum = df[col].max()
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        quantile_9 = df[col].quantile(0.99)

        # Count outliers
        outlier_count = df[(df[col] < lower_bound) | (df[col] > upper_bound)].shape[0]
        outlier_summary[col] = {
            "Mean": mean,
            "Median": median,
            "Mode": mode,
            "Outliers": outlier_count,
            "min_value": min_value,
            "max_value": maximum,
            "99_quantile": quantile_9,
        }
    # print(outlier_summary)
    return outlier_summary

# %%
columns = X_train.columns.tolist()
outlier_summary = outlier_analysis(X_train, columns)
for key, value in outlier_summary.items():
    print(key, value, "\n")
# Out:
# total_items {'Mean': np.float64(0.005344160412757974), 'Median': np.float64(0.004878048780487804), 'Mode': np.float64(0.0024390243902439024), 'Outliers': 10103, 'min_value': np.float64(0.0), 'max_value': np.float64(1.0), '99_quantile': np.float64(0.026829268292682926)}
#
# subtotal {'Mean': np.float64(0.11894882766518247), 'Median': np.float64(0.09777777777777778), 'Mode': np.float64(0.06666666666666667), 'Outliers': 6223, 'min_value': np.float64(0.0), 'max_value': np.float64(1.0), '99_quantile': np.float64(0.41555555555555557)}
#
# max_item_price {'Mean': np.float64(0.07866857239210746), 'Median': np.float64(0.07401360544217687), 'Mode': np.float64(0.07448979591836734), 'Outliers': 5434, 'min_value': np.float64(0.0), 'max_value': np.float64(1.0), '99_quantile': np.float64(0.20849251700680843)}
#
# total_onshift_dashers {'Mean': np.float64(0.28200045828751563), 'Median': np.float64(0.2312138728323699), 'Mode': np.float64(0.023121387283236993), 'Outliers': 1248, 'min_value': np.float64(0.0), 'max_value': np.float64(0.9999999999999999), '99_quantile': np.float64(0.8092485549132947)}
#
# total_busy_dashers {'Mean': np.float64(0.29366376101208336), 'Median': np.float64(0.24528301886792453), 'Mode': np.float64(0.031446540880503145), 'Outliers': 433, 'min_value': np.float64(0.0), 'max_value': np.float64(1.0), '99_quantile': np.float64(0.8238993710691824)}
#
# total_outstanding_orders {'Mean': np.float64(0.21843426548963932), 'Median': np.float64(0.16151202749140894), 'Mode': np.float64(0.020618556701030927), 'Outliers': 4216, 'min_value': np.float64(0.0), 'max_value': np.float64(0.993127147766323), '99_quantile': np.float64(0.738831615120275)}
#
# distance {'Mean': np.float64(0.2603797571744222), 'Median': np.float64(0.2595785440613027), 'Mode': np.float64(0.2629310344827586), 'Outliers': 220, 'min_value': np.float64(0.0), 'max_value': np.float64(0.8194444444444444), '99_quantile': np.float64(0.4980842911877395)}

# %%
# X_train=X_train_copy.copy()
# Removing negative values

X_train = X_train[(X_train["total_onshift_dashers"] >= 0)]
X_train = X_train[X_train["total_busy_dashers"] >= 0]
X_train = X_train[X_train["total_outstanding_orders"] >= 0]
y_train = y_train.loc[X_train.index]
X_test = X_test[
    (X_test["total_outstanding_orders"] >= 0)
    & (X_test["total_busy_dashers"] >= 0)
    & (X_test["total_outstanding_orders"] >= 0)
]
y_test = y_test.loc[X_test.index]
print(X_train.shape, y_train.shape)
# Out:
# (138944, 11) (138944,)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (35156, 11) (35156,)

# %%
for key, value in outlier_analysis(X_train, X_train.columns.tolist()).items():
    print(key, value, "\n\n")
# Out:
# total_items {'Mean': np.float64(0.005344160412757974), 'Median': np.float64(0.004878048780487804), 'Mode': np.float64(0.0024390243902439024), 'Outliers': 10103, 'min_value': np.float64(0.0), 'max_value': np.float64(1.0), '99_quantile': np.float64(0.026829268292682926)}
#
#
# subtotal {'Mean': np.float64(0.11894882766518247), 'Median': np.float64(0.09777777777777778), 'Mode': np.float64(0.06666666666666667), 'Outliers': 6223, 'min_value': np.float64(0.0), 'max_value': np.float64(1.0), '99_quantile': np.float64(0.41555555555555557)}
#
#
# max_item_price {'Mean': np.float64(0.07866857239210746), 'Median': np.float64(0.07401360544217687), 'Mode': np.float64(0.07448979591836734), 'Outliers': 5434, 'min_value': np.float64(0.0), 'max_value': np.float64(1.0), '99_quantile': np.float64(0.20849251700680843)}
#
#
# total_onshift_dashers {'Mean': np.float64(0.28200045828751563), 'Median': np.float64(0.2312138728323699), 'Mode': np.float64(0.023121387283236993), 'Outliers': 1248, 'min_value': np.float64(0.0), 'max_value': np.float64(0.9999999999999999), '99_quantile': np.float64(0.8092485549132947)}
#
#
# total_busy_dashers {'Mean': np.float64(0.29366376101208336), 'Median': np.float64(0.24528301886792453), 'Mode': np.float64(0.031446540880503145), 'Outliers': 433, 'min_value': np.float64(0.0), 'max_value': np.float64(1.0), '99_quantile': np.float64(0.8238993710691824)}
#
#
# total_outstanding_orders {'Mean': np.float64(0.21843426548963932), 'Median': np.float64(0.16151202749140894), 'Mode': np.float64(0.020618556701030927), 'Outliers': 4216, 'min_value': np.float64(0.0), 'max_value': np.float64(0.993127147766323), '99_quantile': np.float64(0.738831615120275)}
#
#
# distance {'Mean': np.float64(0.2603797571744222), 'Median': np.float64(0.2595785440613027), 'Mode': np.float64(0.2629310344827586), 'Outliers': 220, 'min_value': np.float64(0.0), 'max_value': np.float64(0.8194444444444444), '99_quantile': np.float64(0.4980842911877395)}

# %%
X_train[numeric_vars].describe()
# Out:
#          total_items       subtotal  max_item_price  total_onshift_dashers  \
# count  138878.000000  138878.000000   138878.000000          138878.000000
# mean        3.191189    2676.358682     1156.438774              44.804901
# std         2.710761    1802.011909      558.592956              34.512832
# min         1.000000       0.000000        0.000000               0.000000
# 25%         2.000000    1400.000000      799.000000              17.000000
# 50%         3.000000    2200.000000     1088.000000              37.000000
# 75%         4.000000    3395.000000     1395.000000              65.000000
# max       411.000000   22500.000000    14700.000000             169.000000
#
#        total_busy_dashers  total_outstanding_orders       distance
# count       138878.000000             138878.000000  138878.000000
# mean            41.710184                 57.590698      21.746434
# std             32.090449                 52.030696       8.705108
# min              0.000000                  0.000000       0.000000
# 25%             15.000000                 17.000000      15.280000
# 50%             34.000000                 41.000000      21.680000
# 75%             62.000000                 84.000000      28.000000
# max            154.000000                283.000000      68.440000

# %%
X_train = X_train[X_train["distance"] < 70]

X_train = X_train[X_train["total_items"] <= 66]
y_train = y_train.loc[X_train.index]
X_test = X_test[X_test["distance"] < 70]
X_test = X_test[X_test["total_items"] <= 66]
y_test = y_test.loc[X_test.index]

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (138944, 11) (138944,) (35156, 11) (35156,)

# %%
# Handle outliers
def outlier_analysis(df, columns):
    # print(columns)
    outlier_summary = {}
    for col in columns:
        # print(col)
        if df[col].dtype not in ("float64", "int64", "int32"):
            continue
        min_value = df[col].min()
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        mean = df[col].mean()
        median = df[col].median()
        mode = df[col].mode()[0]
        maximum = df[col].max()
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        quantile_9 = df[col].quantile(0.99)

        # Count outliers
        outlier_count = df[(df[col] < lower_bound) | (df[col] > upper_bound)].shape[0]
        outlier_summary[col] = {
            "Mean": mean,
            "Median": median,
            "Mode": mode,
            "Outliers": outlier_count,
            "min_value": min_value,
            "max_value": maximum,
            "99_quantile": quantile_9,
        }
    # print(outlier_summary)
    return outlier_summary

# %% [markdown]
# ## **4. Exploratory Data Analysis on Validation Data** <font color = red>[optional]</font> <br>
# Optionally, perform EDA on test data to see if the distribution match with the training data

# %%
# Define numerical and categorical columns for easy EDA and data manipulation
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140587 entries, 42111 to 38408
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   market_id                 140587 non-null  category
#  1   created_at                140587 non-null  datetime64[ns]
#  2   actual_delivery_time      140587 non-null  datetime64[ns]
#  3   store_primary_category    140587 non-null  category
#  4   order_protocol            140587 non-null  category
#  5   total_items               140587 non-null  int64
#  6   subtotal                  140587 non-null  int64
#  7   num_distinct_items        140587 non-null  int64
#  8   max_item_price            140587 non-null  int64
#  9   total_outstanding_orders  140587 non-null  float64
#  10  distance                  140587 non-null  float64
#  11  time_taken                140587 non-null  float64
#  12  pickup_hour               140587 non-null  int64
#  13  day_of_week               140587 non-null  int64
#  14  isWeekend                 140587 non-null  category
# dtypes: category(4), datetime64[ns](2), float64(3), int64(6)
# memory usage: 13.4 MB

# %% [markdown]
# #### **4.1 Feature Distributions**

# %% [markdown]
# ##### **4.1.1**
# Plot distributions for numerical columns in the validation set to understand their spread and any skewness

# %%
# Plot distributions for all numerical columns

# %% [markdown]
# ##### **4.1.2**
# Check the distribution of categorical features

# %%
# Distribution of categorical columns

# %% [markdown]
# ##### **4.1.3**
# Visualise the distribution of the target variable to understand its spread and any skewness

# %%
# Distribution of time_taken

# %% [markdown]
# #### **4.2 Relationships Between Features**
# Scatter plots for numerical features to observe how they relate to each other, especially to `time_taken`

# %%
# Scatter plot to visualise the relationship between time_taken and other features

# %% [markdown]
# #### **4.3** Drop the columns with weak correlations with the target variable

# %%
# Drop the weakly correlated columns from training dataset

# %% [markdown]
# ## **5. Model Building** <font color = red>[15 marks]</font> <br>

# %% [markdown]
# #### **Import Necessary Libraries**

# %%
# Import libraries
import statsmodels.api as sm
import sklearn
from sklearn.preprocessing import MinMaxScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

# %% [markdown]
# #### **5.1 Feature Scaling** <font color = red>[3 marks]</font> <br>

# %%
X_train.info()
X_copy = X_train.copy()
X_copy["num_distinct_items"] = X_train["num_distinct_items"].astype("category")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140621 entries, 143786 to 43567
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   market_id                 140621 non-null  category
#  1   store_primary_category    140621 non-null  category
#  2   order_protocol            140621 non-null  category
#  3   total_items               140621 non-null  int64
#  4   subtotal                  140621 non-null  int64
#  5   num_distinct_items        140621 non-null  category
#  6   min_item_price            140621 non-null  int64
#  7   max_item_price            140621 non-null  int64
#  8   total_onshift_dashers     140621 non-null  float64
#  9   total_busy_dashers        140621 non-null  float64
#  10  total_outstanding_orders  140621 non-null  float64
#  11  distance                  140621 non-null  float64
#  12  pickup_hour               140621 non-null  category
#  13  isWeekend                 140621 non-null  category
# dtypes: category(6), float64(4), int64(4)
# memory usage: 10.5 MB

# %%
numeric_vars, categorical_vars = categorize(X_train, X_train.columns.tolist())

# %%
numeric_vars
# Out:
# ['total_items',
#  'subtotal',
#  'min_item_price',
#  'max_item_price',
#  'total_onshift_dashers',
#  'total_busy_dashers',
#  'total_outstanding_orders',
#  'distance']

# %%
# Apply scaling to the numerical columns
numeric_vars = [
    "total_items",
    "subtotal",
    "max_item_price",
    "total_onshift_dashers",
    "total_busy_dashers",
    "total_outstanding_orders",
    "distance",
]
scaler = MinMaxScaler()
X_train1, X_test1 = X_train.copy(), X_test.copy()
X_train1[numeric_vars] = scaler.fit_transform(X_train1[numeric_vars])
X_test1[numeric_vars] = scaler.transform(X_test1[numeric_vars])

# %% [markdown]
# XNote that linear regression is agnostic to feature scaling. However, with feature scaling, we get the coefficients to be somewhat on the same scale so that it becomes easier to compare them.

# %% [markdown]
# #### **5.2 Build a linear regression model** <font color = red>[5 marks]</font> <br>

# %% [markdown]
# You can choose from the libraries *statsmodels* and *scikit-learn* to build the model.

# %%
# Create/Initialise the model
lm = LinearRegression()

# %%
# Train the model using the training data
lm.fit(X_train1, y_train)
# Out:
# LinearRegression()

# %%
coefficients = lm.coef_
coefficients
# Out:
# array([ -0.65848517, -13.83775292,  28.14821259,   0.50176811,
#          9.28092479, -60.85491358, -21.59504569,  97.37873845,
#         31.95355516,  -0.24161473,   1.42355385])

# %%
# Make predictions
y_pred = lm.predict(X_test1)

# %%
y_pred
# Out:
# array([44.00064083, 30.88895306, 46.0417225 , ..., 46.41646965,
#        41.64053524, 47.20922927], shape=(35156,))

# %%
# Find results for evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

n = len(X.columns)
p = len(X_train1.columns)
adjusted_r2 = (1 - r2) * (n - 1) / (n - p - 1)
print(f"Mean absolute error:", mae)
print(f"Mean squared error:", mse)
print(f"Root Mean Squared Error:", rmse)
print(f"R-squared:", r2)
print(f"Adjusted R-squared", adjusted_r2)
# Out:
# Mean absolute error: 2.3576780502299663
# Mean squared error: 11.121969347273291
# Root Mean Squared Error: 3.3349616710351095
# R-squared: 0.870465906151783
# Adjusted R-squared 0.8419716100134106

# %% [markdown]
# Note that we have 12 (depending on how you select features) training features. However, not all of them would be useful. Let's say we want to take the most relevant 8 features.
#
# We will use Recursive Feature Elimination (RFE) here.
#
# For this, you can look at the coefficients / p-values of features from the model summary and perform feature elimination, or you can use the RFE module provided with *scikit-learn*.

# %% [markdown]
# #### **5.3 Build the model and fit RFE to select the most important features** <font color = red>[7 marks]</font> <br>

# %% [markdown]
# For RFE, we will start with all features and use
# the RFE method to recursively reduce the number of features one-by-one.
#
# After analysing the results of these iterations, we select the one that has a good balance between performance and number of features.

# %%
X_train_lm = sm.add_constant(X_train1)
lm = sm.OLS(y_train, X_train_lm)
lm = lm.fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             time_taken   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                 8.989e+04
# Date:                Fri, 16 May 2025   Prob (F-statistic):               0.00
# Time:                        07:46:31   Log-Likelihood:            -3.5319e+05
# No. Observations:              138944   AIC:                         7.064e+05
# Df Residuals:                  138932   BIC:                         7.065e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       35.9298      0.041    886.753      0.000      35.850      36.009
# order_protocol              -0.6585      0.006   -118.266      0.000      -0.669      -0.648
# total_items                -13.8378      1.922     -7.200      0.000     -17.605     -10.071
# subtotal                    28.1482      0.189    149.046      0.000      27.778      28.518
# num_distinct_items           0.5018      0.009     54.921      0.000       0.484       0.520
# max_item_price               9.2809      0.298     31.170      0.000       8.697       9.865
# total_onshift_dashers      -60.8549      0.144   -423.383      0.000     -61.137     -60.573
# total_busy_dashers         -21.5950      0.136   -158.508      0.000     -21.862     -21.328
# total_outstanding_orders    97.3787      0.148    658.360      0.000      97.089      97.669
# distance                    31.9536      0.065    491.849      0.000      31.826      32.081
# pickup_hour                 -0.2416      0.001   -231.821      0.000      -0.244      -0.240
# isWeekend                    1.4236      0.018     81.209      0.000       1.389       1.458
# ==============================================================================
# Omnibus:                    34867.150   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            97401.254
# Skew:                           1.331   Prob(JB):                         0.00
# Kurtosis:                       6.120   Cond. No.                     2.93e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.93e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
vif = pd.DataFrame()
t = X_train1
vif["Features"] = t.columns
vif["VIF"] = [variance_inflation_factor(t.values, i) for i in range(t.shape[1])]
vif["VIF"] = round(vif["VIF"], 2)
vif = vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                     Features    VIF
# 5      total_onshift_dashers  35.99
# 6         total_busy_dashers  34.47
# 7   total_outstanding_orders  25.83
# 3         num_distinct_items  10.40
# 2                   subtotal  10.30
# 4             max_item_price   7.71
# 8                   distance   5.54
# 0             order_protocol   4.16
# 1                total_items   3.92
# 9                pickup_hour   2.02
# 10                 isWeekend   1.56

# %%
# Out:
# 143786    44.0
# 165941    35.0
# 53920     49.0
# 150506    39.0
# 69767     43.0
#           ...
# 95939     32.0
# 152315    38.0
# 117952    47.0
# 173685    55.0
# 43567     70.0
# Name: time_taken, Length: 138944, dtype: float64

# %%
# Loop through the number of features and test the model
p = len(X_train1.columns)
for i in range(p, 7, -1):
    rfe = RFE(estimator=LinearRegression(), n_features_to_select=i)
    rfe.fit(X_train1, y_train)
    col = X_train1.columns[rfe.support_]

    lm = LinearRegression()
    lm.fit(X_train1[col], y_train)

    y_pred = lm.predict(X_test1[col])
    r2 = r2_score(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred)
    n = len(X.columns)
    p = len(col)
    adjusted_r2 = (1 - r2) * (n - 1) / (n - i - 1)
    print(
        f"Selected Features: {col}, r2_score: {r2}, RMSE: {rmse}, Adjusted r2: {adjusted_r2}"
    )
# Out:
# Selected Features: Index(['order_protocol', 'total_items', 'subtotal', 'num_distinct_items',
#        'max_item_price', 'total_onshift_dashers', 'total_busy_dashers',
#        'total_outstanding_orders', 'distance', 'pickup_hour', 'isWeekend'],
#       dtype='object'), r2_score: 0.870465906151783, RMSE: 11.121969347273291, Adjusted r2: 0.8419716100134106
# Selected Features: Index(['order_protocol', 'total_items', 'subtotal', 'num_distinct_items',
#        'max_item_price', 'total_onshift_dashers', 'total_busy_dashers',
#        'total_outstanding_orders', 'distance', 'isWeekend'],
#       dtype='object'), r2_score: 0.8255076825079187, RMSE: 14.982142143640125, Adjusted r2: 0.7561333757990188
# Selected Features: Index(['order_protocol', 'total_items', 'subtotal', 'max_item_price',
#        'total_onshift_dashers', 'total_busy_dashers',
#        'total_outstanding_orders', 'distance', 'isWeekend'],
#       dtype='object'), r2_score: 0.8222287384162237, RMSE: 15.263676638504371, Adjusted r2: 0.577756600147273
# Selected Features: Index(['total_items', 'subtotal', 'max_item_price', 'total_onshift_dashers',
#        'total_busy_dashers', 'total_outstanding_orders', 'distance',
#        'isWeekend'],
#       dtype='object'), r2_score: 0.8081158562466491, RMSE: 16.475427446562758, Adjusted r2: 0.49889877375871244

# %%
p = len(X_train1.columns)
for i in range(p, 7, -1):
    rfe = RFE(estimator=LinearRegression(), n_features_to_select=i)
    rfe.fit(X_train1, y_train)
    col = X_train1.columns[rfe.support_]

    lm = LinearRegression()
    lm.fit(X_train1[col], y_train)

    y_pred = lm.predict(X_test1[col])
    r2 = r2_score(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred)
    n = len(X.columns)
    p = len(col)
    adjusted_r2 = (1 - r2) * (n - 1) / (n - i - 1)
    print(
        f"Selected Features: {col}, r2_score: {r2}, RMSE: {rmse}, Adjusted r2: {adjusted_r2}"
    )
# Out:
# Selected Features: Index(['order_protocol', 'total_items', 'subtotal', 'num_distinct_items',
#        'max_item_price', 'total_onshift_dashers', 'total_busy_dashers',
#        'total_outstanding_orders', 'distance', 'pickup_hour', 'isWeekend'],
#       dtype='object'), r2_score: 0.870465906151783, RMSE: 11.121969347273291, Adjusted r2: 0.8419716100134106
# Selected Features: Index(['order_protocol', 'total_items', 'subtotal', 'num_distinct_items',
#        'max_item_price', 'total_onshift_dashers', 'total_busy_dashers',
#        'total_outstanding_orders', 'distance', 'isWeekend'],
#       dtype='object'), r2_score: 0.8255076825079187, RMSE: 14.982142143640125, Adjusted r2: 0.7561333757990188
# Selected Features: Index(['order_protocol', 'total_items', 'subtotal', 'max_item_price',
#        'total_onshift_dashers', 'total_busy_dashers',
#        'total_outstanding_orders', 'distance', 'isWeekend'],
#       dtype='object'), r2_score: 0.8222287384162237, RMSE: 15.263676638504371, Adjusted r2: 0.577756600147273
# Selected Features: Index(['total_items', 'subtotal', 'max_item_price', 'total_onshift_dashers',
#        'total_busy_dashers', 'total_outstanding_orders', 'distance',
#        'isWeekend'],
#       dtype='object'), r2_score: 0.8081158562466491, RMSE: 16.475427446562758, Adjusted r2: 0.49889877375871244

# %%
col = X_train1.columns[rfe.support_]

# %%
X_train1.columns[~rfe.support_]
# Out:
# Index(['order_protocol', 'num_distinct_items', 'pickup_hour'], dtype='object')

# %%
X_train_rfe = X_train1[col]

# %%
X_train_rfe.head()
# Out:
#         total_items  subtotal  max_item_price  total_onshift_dashers  \
# 143786     0.004878  0.110889        0.098639               0.127168
# 165941     0.002439  0.047733        0.054354               0.231214
# 53920      0.004878  0.123333        0.062925               0.104046
# 150506     0.002439  0.073111        0.064626               0.514451
# 69767      0.004878  0.107778        0.066327               0.601156
#
#         total_busy_dashers  total_outstanding_orders  distance isWeekend
# 143786            0.144654                  0.103806  0.239626         1
# 165941            0.251572                  0.190311  0.239041         0
# 53920             0.088050                  0.058824  0.438340         0
# 150506            0.735849                  0.366782  0.504383         0
# 69767             0.522013                  0.491349  0.158971         1

# %%
vif = pd.DataFrame()
t = X_train_rfe
vif["Features"] = t.columns
vif["VIF"] = [variance_inflation_factor(t.values, i) for i in range(t.shape[1])]
vif["VIF"] = round(vif["VIF"], 2)
vif = vif.sort_values(by="VIF", ascending=False)
vif
# Out:
#                    Features    VIF
# 3     total_onshift_dashers  35.63
# 4        total_busy_dashers  33.98
# 5  total_outstanding_orders  25.49
# 1                  subtotal   7.65
# 2            max_item_price   7.29
# 6                  distance   4.26
# 0               total_items   2.79
# 7                 isWeekend   1.53

# %%
# Build the final model with selected number of features
col = X_train1.columns[rfe.support_]
X_train_rfe_sm = sm.add_constant(X_train_rfe)
lm_stats = sm.OLS(y_train, X_train_rfe_sm)
rfe_model = lm_stats.fit()
print(rfe_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             time_taken   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                 7.396e+04
# Date:                Fri, 16 May 2025   Prob (F-statistic):               0.00
# Time:                        08:18:24   Log-Likelihood:            -3.8334e+05
# No. Observations:              138944   AIC:                         7.667e+05
# Df Residuals:                  138935   BIC:                         7.668e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       30.9893      0.038    813.308      0.000      30.915      31.064
# total_items                 43.1062      2.068     20.845      0.000      39.053      47.159
# subtotal                    36.1695      0.198    182.567      0.000      35.781      36.558
# max_item_price              12.9064      0.353     36.600      0.000      12.215      13.598
# total_onshift_dashers      -57.7994      0.178   -325.525      0.000     -58.147     -57.451
# total_busy_dashers         -23.2400      0.169   -137.494      0.000     -23.571     -22.909
# total_outstanding_orders    99.0890      0.184    539.716      0.000      98.729      99.449
# distance                    32.0707      0.081    397.396      0.000      31.913      32.229
# isWeekend                    1.2912      0.022     59.373      0.000       1.249       1.334
# ==============================================================================
# Omnibus:                    18582.770   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34280.787
# Skew:                           0.869   Prob(JB):                         0.00
# Kurtosis:                       4.703   Cond. No.                         248.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_train_pred = rfe_model.predict(X_train_rfe_sm)
y_train_pred
# Out:
# 143786    45.033667
# 165941    40.835865
# 53920     48.299153
# 150506    40.256821
# 69767     44.152675
#             ...
# 95939     34.564338
# 152315    34.637265
# 117952    46.489563
# 173685    52.778845
# 43567     77.287863
# Length: 138944, dtype: float64

# %%
X_test_new = X_test[col]
X_test_new_sm = sm.add_constant(X_test_new)
y_test_pred = rfe_model.predict(X_test_new_sm)
y_test_pred
# Out:
# 119426    42.901030
# 5638      26.019413
# 86872     43.223120
# 108139    43.005915
# 144775    44.638941
#             ...
# 161722    33.544417
# 97399     38.660970
# 125821    43.336643
# 167096    42.016141
# 63074     44.147412
# Length: 35156, dtype: float64

# %%
mae = mean_absolute_error(y_test, y_test_pred)
mse = mean_squared_error(y_test, y_test_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_test_pred)
r2_train = r2_score(y_train, y_train_pred)
print(f"Mean absolute error:", mae)
print(f"Mean squared error:", mse)
print(f"Root Mean Squared Error:", rmse)
print(f"Test R-squared:", r2)
print(f"Train R-squared", r2_train)
# Out:
# Mean absolute error: 3.382022506662342
# Mean squared error: 21.727365654238984
# Root Mean Squared Error: 4.661262238304018
# Test R-squared: 0.7469481767254899
# Train R-squared 0.8098445374802055

# %%
scaled_coeff = rfe_model.params

# %%
standrdised_res = (y_train - y_train_pred) / (y_train - y_train_pred).std()

# %% [markdown]
# ## **6. Results and Inference** <font color = red>[5 marks]</font> <br>

# %% [markdown]
# #### **6.1 Perform Residual Analysis** <font color = red>[3 marks]</font> <br>

# %%
# Perform residual analysis using plots like residuals vs predicted values, Q-Q plot and residual histogram
res = y_test - y_test_pred
res1 = res / res.std()
fig = plt.figure()

sns.distplot(res1, bins=20)
fig.suptitle("Error Terms", fontsize=20)
plt.xlabel("Errors", fontsize=10)
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x=y_test_pred, y=res1)
plt.xlabel("Predicted test values")
plt.ylabel("Residuals")
plt.title("Residuals vs predicted\n\n", fontdict={"fontsize": 20, "color": "brown"})
plt.show()

# %%
stats.probplot(res1, dist="norm", plot=plt)
plt.title("Normality of error terms", fontdict={"fontsize": 20, "color": "brown"})
plt.show()

# %%
print(rfe_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             time_taken   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                 7.396e+04
# Date:                Fri, 16 May 2025   Prob (F-statistic):               0.00
# Time:                        08:48:39   Log-Likelihood:            -3.8334e+05
# No. Observations:              138944   AIC:                         7.667e+05
# Df Residuals:                  138935   BIC:                         7.668e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       30.9893      0.038    813.308      0.000      30.915      31.064
# total_items                 43.1062      2.068     20.845      0.000      39.053      47.159
# subtotal                    36.1695      0.198    182.567      0.000      35.781      36.558
# max_item_price              12.9064      0.353     36.600      0.000      12.215      13.598
# total_onshift_dashers      -57.7994      0.178   -325.525      0.000     -58.147     -57.451
# total_busy_dashers         -23.2400      0.169   -137.494      0.000     -23.571     -22.909
# total_outstanding_orders    99.0890      0.184    539.716      0.000      98.729      99.449
# distance                    32.0707      0.081    397.396      0.000      31.913      32.229
# isWeekend                    1.2912      0.022     59.373      0.000       1.249       1.334
# ==============================================================================
# Omnibus:                    18582.770   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34280.787
# Skew:                           0.869   Prob(JB):                         0.00
# Kurtosis:                       4.703   Cond. No.                         248.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif
# Out:
#                    Features    VIF
# 3     total_onshift_dashers  35.63
# 4        total_busy_dashers  33.98
# 5  total_outstanding_orders  25.49
# 1                  subtotal   7.65
# 2            max_item_price   7.29
# 6                  distance   4.26
# 0               total_items   2.79
# 7                 isWeekend   1.53

# %% [markdown]
# [Your inferences here:]

# %% [markdown]
# #### **6.2 Perform Coefficient Analysis** <font color = red>[2 marks]</font> <br>

# %% [markdown]
# Perform coefficient analysis to find how changes in features affect the target.
# Also, the features were scaled, so interpret the scaled and unscaled coefficients to understand the impact of feature changes on delivery time.

# %%
# Compare the scaled vs unscaled features used in the final model
scaled_train, scaled_y_train = df_train, df_train.pop("time_taken")
scaled_test, scaled_y_test = df_test, df_test.pop("time_taken")
scaled_train = scaled_train[col]
scaled_test = scaled_test[col]
lm = LinearRegression()
lm.fit(scaled_train, scaled_y_train)
unscaled_coef = lm.coef_

# %%
f = pd.DataFrame({"Unscaled Coeff": unscaled_coef, "scaled_ceff": scaled_coeff})
f
# Out:
#                           Unscaled Coeff  scaled_ceff
# total_items                     0.105632    43.106212
# subtotal                        0.001642    36.169533
# max_item_price                  0.000913    12.906367
# total_onshift_dashers          -0.347114   -57.799373
# total_busy_dashers             -0.150802   -23.240025
# total_outstanding_orders        0.353675    99.089025
# distance                        0.478092    32.070712
# isWeekend                       1.068274     1.291171

# %% [markdown]
# scaled_train=scaled_train.columns[rfe.support_]
# Additionally, we can analyse the effect of a unit change in a feature. In other words, because we have scaled the features, a unit change in the features will not translate directly to the model. Use scaled and unscaled coefficients to find how will a unit change in a feature affect the target.

# %%
# Analyze the effect of a unit change in a feature, say 'total_items'
diff = 0.1015632
f["Unit_Change"] = f["Unscaled Coeff"] + diff
f
# Out:
#                           Unscaled Coeff  scaled_ceff  Unit_Change
# total_items                     0.105632    43.106212     0.207195
# subtotal                        0.001642    36.169533     0.103205
# max_item_price                  0.000913    12.906367     0.102476
# total_onshift_dashers          -0.347114   -57.799373    -0.245551
# total_busy_dashers             -0.150802   -23.240025    -0.049238
# total_outstanding_orders        0.353675    99.089025     0.455238
# distance                        0.478092    32.070712     0.579655
# isWeekend                       1.068274     1.291171     1.169838

# %% [markdown]
# Note:
# The coefficients on the original scale might differ greatly in magnitude from the scaled coefficients, but they both describe the same relationships between variables.
#
# Interpretation is key: Focus on the direction and magnitude of the coefficients on the original scale to understand the impact of each variable on the response variable in the original units.

# %% [markdown]
# Include conclusions in your report document.

# %% [markdown]
# ## Subjective Questions <font color = red>[20 marks]</font>

# %% [markdown]
# Answer the following questions only in the notebook. Include the visualisations/methodologies/insights/outcomes from all the above steps in your report.

# %% [markdown]
# #### Subjective Questions based on Assignment

# %% [markdown]
# ##### **Question 1.** <font color = red>[2 marks]</font> <br>
#
# Are there any categorical variables in the data? From your analysis of the categorical variables from the dataset, what could you infer about their effect on the dependent variable?

# %% [markdown]
# **Answer:**
# > Yes, in the original dataset provided and including derived metrics, we have the following categorical variables:
# 1. Market_Id
# 2. store_primary_category
# 3. order_protocol
# 4. pickup_hour
# 5. isWeekend
# From what we can infer, isWeekend has an impact on dependent variable as included in the final model

# %% [markdown]
# ---

# %% [markdown]
# ##### **Question 2.** <font color = red>[1 marks]</font> <br>
# What does `test_size = 0.2` refer to during splitting the data into training and test sets?

# %% [markdown]
# **Answer:**
# > It means 20% of the data will be used for validation to test the accuracy of the model built by the remaining data

# %% [markdown]
# ---

# %% [markdown]
# ##### **Question 3.** <font color = red>[1 marks]</font> <br>
# Looking at the heatmap, which one has the highest correlation with the target variable?

# %% [markdown]
# **Answer:**
# > distance has the highest correlation of .46

# %% [markdown]
# ---

# %% [markdown]
# ##### **Question 4.** <font color = red>[2 marks]</font> <br>
# What was your approach to detect the outliers? How did you address them?

# %% [markdown]
# **Answer:**
#
# > Using various algorithms and box plots, I made a function to detect outliers and check for negative values.
# Using that I first removed the negative values, then visualising the box plots, removed outliers above and below IQR's upper bound and lower bound

# %% [markdown]
# ---

# %% [markdown]
# ##### **Question 5.** <font color = red>[2 marks]</font> <br>
# Based on the final model, which are the top 3 features significantly affecting the delivery time?

# %% [markdown]
# **Answer:**
# > Based on the final model I got the top three were: total_items, distance followed by subtotal

# %% [markdown]
# ---

# %% [markdown]
# #### General Subjective Questions

# %% [markdown]
# ##### **Question 6.** <font color = red>[3 marks]</font> <br>
# Explain the linear regression algorithm in detail

# %% [markdown]
# **Answer:**
# > A linear regression model is a type of supervised learning algorithm used
# to establish a relationship between a dependent variable (target variable)
# and one or more independent variables (predictor variables). The aim is to create a model that establishes a linear equation between the dependent and independent variables by minimizing the loss using various approaches, the most common ones are minimizing loss by minimizing Mean Squared Error or using Gradient Descent
#
# **Assumptions**
#
# Linear regression assumes the following:
#
# 1. **Linearity**: The relationship between the dependent variable and one
# or more independent variables is linear.
# 2. **Independence**: Each observation is independent of the others.
# 3. **Homoscedasticity**: The variance of the error term is constant across
# all levels of the predictor variables.
# 4. **Normality**: The error term follows a normal distribution.
# 5. **No multicollinearity**: The predictor variables are not highly
# correlated with each other
#
# **Simple Linear Regression**
# y = β0 + β1x + ε
# Here y is the dependent variable, ε is the error term, β0 is the slope and β1 is the slope coefficient
#
# **Multiple Linear Regression**
# This model includes multiple independent variables and is used to analyze
# relationships between more than two variables.
#
# The linear regression model can be estimated using various methods,
# including:
#
# 1. **Ordinary Least Squares (OLS)**: This is the most commonly used method
# for estimating linear regression models. OLS minimizes the sum of the
# squared errors between observed and predicted values.
# 2. **Gradient Descent**: It uses an iterative approach to minimize the loss

# %% [markdown]
# ---

# %% [markdown]
# ##### **Question 7.** <font color = red>[2 marks]</font> <br>
# Explain the difference between simple linear regression and multiple linear regression

# %% [markdown]
# **Answer:**
# > In simple linear regression, there is only 1 independent variable, whereas in multiple linear regression, the feature which we are trying to predict is dependent on 2 or more than 2 variables.

# %% [markdown]
# ---

# %% [markdown]
# ##### **Question 8.** <font color = red>[2 marks]</font> <br>
# What is the role of the cost function in linear regression, and how is it minimized?

# %% [markdown]
# **Answer:**
# > Cost Function tells how far the predicted values are from actual values. It is minimized using techniques like Mean Squared Error (MSE) or its variant, the Mean Absolute Error (MAE). The goal is to find the optimal parameters that minimize the MSE, which measures the average squared difference between predicted and actual values.
# Other techniques include gradient descent or stochastic gradient descent

# %% [markdown]
# ---

# %% [markdown]
# ##### **Question 9.** <font color = red>[2 marks]</font> <br>
# Explain the difference between overfitting and underfitting.

# %% [markdown]
# **Answer:**
#
# > **Overfitting**
#
# Overfitting occurs when a model is too complex and learns the noise in the
# training data, rather than the underlying patterns or relationships. As a
# result, the model performs well on the training data but poorly on new,
# unseen data.
#
#
# **Underfitting**
#
# Underfitting occurs when a model is too simple and fails to capture the
# underlying patterns or relationships in the training data. As a result,
# the model performs poorly on both the training and new data.

# %% [markdown]
# ---

# %% [markdown]
# ##### **Question 10.** <font color = red>[3 marks]</font> <br>
# How do residual plots help in diagnosing a linear regression model?

# %% [markdown]
# **Answer:**
# > Residual plots determine if our residuals are normally distributed, which tells whether our linear regression model is valid or not. Non normalcy of error terms means there is some problem with our algorithm
#
# **Quantile-Quantile (Q-Q) Plot**: A Q-Q plot can be used to detect non-normality in the residuals.
#
# **Scatter Plot**: A scatter plot with randomly scattered points
# indicates that the relationship between the independent variable(s) and
# the dependent variable is linear.
#
# **Boxplot Residual Plot**: If the boxplot residual plot shows outliers,
# it suggests that there are extreme values in the data that need to be
# addressed.
