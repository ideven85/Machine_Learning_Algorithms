# %%
import numpy as np
from collections import Counter

words = "A fast moving bike entered into the complex and shoot the couple"

# %%
Counter(words.split(" "))
# Out:
# Counter({'the': 2,
#          'A': 1,
#          'fast': 1,
#          'moving': 1,
#          'bike': 1,
#          'entered': 1,
#          'into': 1,
#          'complex': 1,
#          'and': 1,
#          'shoot': 1,
#          'couple': 1})

# %%
x = np.array([0.09, 0.3, 0.06, 0.04, 0.08])
y = np.array([0.16, 0.06, 0.05, 0.35, 0.07, 0.03])
np.dot(x, x) * 0.1
# Out:
# np.float64(0.01097)

# %%
max(
    0.09 * 0.3 * 0.06 * 0.04 * 0.08 * 0.1, 0.16 * 0.06 * 0.05 * 0.35 * 0.07 * 0.03 * 0.9
)
# Out:
# 5.184000000000001e-07

# %%
# Out:
# 3.1752e-07
