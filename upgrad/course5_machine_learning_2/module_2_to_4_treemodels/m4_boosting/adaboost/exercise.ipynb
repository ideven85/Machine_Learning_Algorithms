# %%
import numpy as np

# %%
a = np.array([0.1] * 10)

# %%
error = 0.2 * (2 / 10) + 0.8 * (0)

# %%
error
# Out:
# 0.04000000000000001

# %%
0.5 * np.log((1 - error) / error)
# Out:
# np.float64(1.5890269151739727)

# %%
0.5 * np.log((1 - 0.2) / 0.2)
# Out:
# np.float64(0.6931471805599453)

# %%
0.1 * np.e ** ((0.5 * np.log((1 - 0.2) / 0.2))) * 2
# Out:
# np.float64(0.39999999999999997)
