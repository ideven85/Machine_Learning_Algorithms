# %%
import numpy as np
import pandas as pd
from sklearn import metrics

# %%
y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
metrics.confusion_matrix(y_true, y_pred, labels=["cat", "ant"])
# Out:
# array([[2, 1],
#        [0, 2]])
