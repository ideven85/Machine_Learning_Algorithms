# %%
import numpy as np

# %%
np.cos([[3, 8], [4, 6]])
# Out:
# array([[-0.9899925 , -0.14550003],
#        [-0.65364362,  0.96017029]])

# %%
(3 * 4 + 8 * 6) / (np.sqrt(73) * np.sqrt(52))
# Out:
# np.float64(0.9738412097417933)
