# %%
# load all necessary libraries
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents = [
    "Gangs of Wasseypur is a great movie. Wasseypur is a town in Bihar.",
    "The success of a song depends on the music.",
    "There is a new movie releasing this week. The movie is fun to watch.",
]
# word_tokenize(documents)

# %%
for x in documents:
    print(x)
# Out:
# Gangs of Wasseypur is a great movie. Wasseypur is a town in Bihar.
# The success of a song depends on the music.
# There is a new movie releasing this week. The movie is fun to watch.

# %%
import numpy as np

# %%
for x in documents:
    print(word_tokenize(x.lower()))
# Out:
# ['gangs', 'of', 'wasseypur', 'is', 'a', 'great', 'movie', '.', 'wasseypur', 'is', 'a', 'town', 'in', 'bihar', '.']
# ['the', 'success', 'of', 'a', 'song', 'depends', 'on', 'the', 'music', '.']
# ['there', 'is', 'a', 'new', 'movie', 'releasing', 'this', 'week', '.', 'the', 'movie', 'is', 'fun', 'to', 'watch', '.']

# %%
def clean_document(doc):
    doc = doc.lower()
    doc = word_tokenize(doc)
    return " ".join(a for a in doc if a not in stopwords.words("english"))

# %%
documents = [doc for doc in [clean_document(x) for x in documents]]
documents
# Out:
# ['gangs wasseypur great movie . wasseypur town bihar .',
#  'success song depends music .',
#  'new movie releasing week . movie fun watch .']

# %%
vectorizer = TfidfVectorizer()


def lp(x):
    print(x)


model = vectorizer.fit_transform(documents)

# %%
dir(model)
# Out:
# ['T',
#  '__abs__',
#  '__abstractmethods__',
#  '__add__',
#  '__array_priority__',
#  '__bool__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__pow__',
#  '__radd__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmatmul__',
#  '__rmul__',
#  '__round__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '_abc_impl',
#  '_add_dense',
# ...

# %%
model.toarray()
# Out:
# array([[0.34142622, 0.        , 0.        , 0.34142622, 0.34142622,
#         0.25966344, 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.34142622, 0.68285244, 0.        , 0.        ],
#        [0.        , 0.5       , 0.        , 0.        , 0.        ,
#         0.        , 0.5       , 0.        , 0.        , 0.5       ,
#         0.5       , 0.        , 0.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.36977238, 0.        , 0.        ,
#         0.56244284, 0.        , 0.36977238, 0.36977238, 0.        ,
#         0.        , 0.        , 0.        , 0.36977238, 0.36977238]])

# %%
import warnings

core_python = """Upper case characters found in"
                        " vocabulary while 'lowercase'"
                        " is True. These entries will not"
                        " be matched with any documents"""
if len([x for x in list(core_python) if x.isupper()]):
    warnings.warn(
        "Upper case characters found in"
        " vocabulary while 'lowercase'"
        " is True. These entries will not"
        " be matched with any documents"
    )
# Out:
# /var/folders/10/w0prq46s3k15tvrn9sm0pwbm0000gn/T/ipykernel_21041/4053385944.py:7: UserWarning: Upper case characters found in vocabulary while 'lowercase' is True. These entries will not be matched with any documents
#   warnings.warn(
