# %%
# import the regular expression module
import re

from numpy.f2py.crackfortran import word_pattern

# input string
string = "The roots of education are bitter, but the fruit is sweet."

# write a regular expression pattern to check if 'education' is present in a given string or not.
pattern = "education"

# store the match of regex
result = re.search(pattern, string)

# store the end of the match using result.end()
end_position = result.start()

# evaluate result - don't change the following piece of code, it is used to evaluate your regex
print(end_position)
# Out:
# 13

# %%
sentence = "The tree stands tall"
re.search("tree", sentence)
# Out:
# <re.Match object; span=(4, 8), match='tree'>

# %%
18000 / 202
# Out:
# 89.10891089108911

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
def find_pattern(text, patterns):
    if re.search(patterns, text):
        return re.search(patterns, text)
    else:
        return "Not Found!"

# %%
def reverse(string: str) -> str:

    return " ".join("".join(reversed(list(el))) for el in string.split(" "))


x = "All is well"
reverse(x)
# Out:
# 'llA si llew'

# %%
# Out:
# 'llA si llew'

# %%
text = "The tree stands tall"
# regex pattern
pattern = text
# Hint: pass the arguments in below re.search() function.

# check whether pattern is present in string or not
result = re.search("tree", pattern)  # pass the arguments to the re.search function

# evaluate result - don't change the following piece of code, it is used to evaluate your regex
if result != None:
    print(True)
else:
    print(False)
# Out:
# True

# %%
string = "01"
pattern = "0001+"

# check whether pattern is present in string or not
result = re.search(pattern, string)

# %%
print(result)
# Out:
# None

# %%
word = "0"
re.sub(word, "000", "1*")
# Out:
# '1*'

# %% [markdown]
# """
# the pipe operator. It’s notated by ‘|’. The pipe operator is used as an OR operator. You need to use it inside the parentheses. For example, the pattern ‘(d|g)one’ will match both the strings - ‘done’ and ‘gone’. The pipe operator tells that the place inside the parentheses can be either ‘d’ or ‘g’.
#
#
#
# Similarly, the pattern ‘(ICICI|HDFC) Bank’ will match the strings ‘ICICI Bank’ and ‘HDFC Bank’. You can also use quantifiers after the parentheses as usual even when there is a pipe operator inside. Not only that, there can be an infinite number of pipe operators inside the parentheses. The pattern ‘(0|1|2){2} means 'exactly two occurrences of either of 0, 1 or 2', and it will match these strings - ‘00’, ‘01’, ‘02’, ‘10’, ‘11’, ‘12’, ‘20’, ‘21’ and ‘22’.
# """

# %%
import re

word = "00"
pattern = "(0|1|2){2}"
re.search(pattern, word)
# Out:
# <re.Match object; span=(0, 2), match='00'>

# %%
word = "Volleyball"
pattern = "(Basket|Base|Volley|Soft|Foot)ball"
re.search(pattern, word)
# Out:
# <re.Match object; span=(0, 10), match='Volleyball'>

# %%
word = "Dravid, who scored 56(78), was bowled by Brett Lee after lunchtime’."
pattern = "\(78\)"
re.search(pattern, word)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\('
# <>:2: SyntaxWarning: invalid escape sequence '\('
# /var/folders/5v/t2smh6m1215gl6lv1byjdtzc0000gn/T/ipykernel_24488/3784205394.py:2: SyntaxWarning: invalid escape sequence '\('
#   pattern = '\(78\)'
# <re.Match object; span=(21, 25), match='(78)'>

# %%
eq = "3a*4b"
pattern = "\\*"
re.search(pattern, eq)
# Out:
# <re.Match object; span=(2, 3), match='*'>

# %% [markdown]
# Now, there are something called as regex flags. A flag has a special meaning. For example, if you want your regex to ignore the case of the text then you can pass the 're.I' flag. Similarly, you can have have a flag with the syntax re.M that enables you to search in multiple lines (in case the input text has multiple lines). You can pass all these flags in the re.search() function. The syntax to pass multiple flags is:
#
#
#
# re.search(pattern, string, flags=re.I | re.M)
#
# Last, you need to know about the re.compile() function. This function stores the regular expression pattern in the cache memory and is said to result in a little faster searches. You need to pass the regex pattern to re.compile() function. The following piece of code shows the difference between searching with the compile function and without the compile function.
#
#
#
# #### without re.compile() function
# result = re.search("a+", "abc")
#
# #### using the re.compile() function
# pattern = re.compile("a+")
# result = pattern.search("abc")
#
#  ,

# %%
pattern = re.compile("a+")
result = pattern.search("abc")
# Out:
# <re.Match object; span=(0, 1), match='a'>
