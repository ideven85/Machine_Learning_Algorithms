# %%
import numpy as np
import pandas as pd

# %%
a = np.array([[1, 1, 1], [3, 4, 1], [4, 1, 2]])
np.linalg.norm(a)
# Out:
# np.float64(7.0710678118654755)

# %%
np.sqrt(50)
# Out:
# np.float64(7.0710678118654755)
