# %%
import numpy as np
import tensorflow as tf

# %%
x = tf.random.normal(shape=(3, 1), mean=0.0, stddev=1.0)

# %%
print(x)
# Out:
# tf.Tensor(
# [[-1.3005686]
#  [-0.7940285]
#  [-1.759279 ]], shape=(3, 1), dtype=float32)

# %%
x
# Out:
# <tf.Tensor: shape=(3, 1), dtype=float32, numpy=
# array([[-1.3005686],
#        [-0.7940285],
#        [-1.759279 ]], dtype=float32)>

# %%
np.mean(x)
# Out:
# np.float32(-1.2846254)

# %%
np.std(x)
# Out:
# np.float32(0.3942231)

# %%
v = tf.Variable(initial_value=x)

# %%
v
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[-1.3005686],
#        [-0.7940285],
#        [-1.759279 ]], dtype=float32)>

# %%
v[0, 0].assign(3)
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[ 3.       ],
#        [-0.7940285],
#        [-1.759279 ]], dtype=float32)>

# %%
v
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[ 3.       ],
#        [-0.7940285],
#        [-1.759279 ]], dtype=float32)>

# %%
v.assign_add(tf.ones((3, 1)))
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[ 4.        ],
#        [ 0.20597148],
#        [-0.759279  ]], dtype=float32)>

# %%
v
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[ 4.        ],
#        [ 0.20597148],
#        [-0.759279  ]], dtype=float32)>

# %%
a = t
a
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>

# %%
b = tf.zeros(shape=2)

# %%
c = tf.square(a)
c
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>

# %%
tf.concat((a, c), axis=0)
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.],
#        [1., 1.]], dtype=float32)>

# %%
tf.matmul(a, c)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[2., 2.],
#        [2., 2.]], dtype=float32)>

# %%
a + c
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[2., 2.],
#        [2., 2.]], dtype=float32)>

# %%
a @ c
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[2., 2.],
#        [2., 2.]], dtype=float32)>

# %%
tf.multiply(a, c)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>

# %%
np.multiply(a, c)
# Out:
# array([[1., 1.],
#        [1., 1.]], dtype=float32)

# %%
np.matmul(a, c)
# Out:
# array([[2., 2.],
#        [2., 2.]], dtype=float32)

# %%
def dense(inp, weight, bias):
    return tf.nn.relu(tf.matmul(inp, weight) + bias)

# %%
a.ndim
# Out:
# 2

# %%
a.shape
# Out:
# TensorShape([2, 2])
