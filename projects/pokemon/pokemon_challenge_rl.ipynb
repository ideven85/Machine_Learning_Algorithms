# %%
import pandas as pd

# %%
df = pd.read_excel("Pokemon.xlsx")

# %%
df
# Out:
#       Card ID         Card Name Expansion  Collection No.  \
# 0         1.0  Basic {G} Energy       SVE             1.0
# 1         2.0  Basic {R} Energy       SVE             2.0
# 2         3.0  Basic {W} Energy       SVE             3.0
# 3         4.0  Basic {L} Energy       SVE             4.0
# 4         5.0  Basic {P} Energy       SVE             5.0
# ...       ...               ...       ...             ...
# 2096   1263.0    Mystery Garden       MEG           122.0
# 2097   1264.0       Battle Cage       PFL            85.0
# 2098   1265.0   Dizzying Valley       PFL            88.0
# 2099   1266.0    Nighttime Mine       ASC           197.0
# 2100   1267.0      Lumiose City       POR            77.0
#
#      Stage (Pokémon)/Type (Energy and Trainer) Rule Category Previous stage  \
# 0                                 Basic Energy  NaN      NaN            NaN
# 1                                 Basic Energy  NaN      NaN            NaN
# ...

# %%
df.to_csv("Pokemon_Proper.csv", index=False)
