# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/px/m0g9wbyn1sv678fsx9lgsm600000gn/T/pip-req-build-m70_qstw
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/px/m0g9wbyn1sv678fsx9lgsm600000gn/T/pip-req-build-m70_qstw
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.34.2)
# Requirement already satisfied: numpy in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.5.1)
# Requirement already satisfied: matplotlib in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (3.11.1)
# Requirement already satisfied: scipy in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.18.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=9 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/deven/.virtualenvs/Machine_Learning_Algorithms/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2026.7.22)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=f4f381343aec4ee416506e20d9e3131d2ad4967bcddfbec30fa5d1e05c4681b6
#   Stored in directory: /private/var/folders/px/m0g9wbyn1sv678fsx9lgsm600000gn/T/pip-ephem-wheel-cache-dzcdx0n7/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(
    args, path="./mnist1d_data.pkl", download=False, regenerate=False
)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data["y"])))
print("Examples in test set: {}".format(len(data["y_test"])))
print("Length of each example: {}".format(data["x"].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data["x"].transpose()
train_data_y = data["y"]
val_data_x = data["x_test"].transpose()
val_data_y = data["y_test"]
# Print out sizes
print(
    "Train data: %d examples (columns), each of which has %d dimensions (rows)"
    % ((train_data_x.shape[1], train_data_x.shape[0]))
)
print(
    "Validation data: %d examples (columns), each of which has %d dimensions (rows)"
    % ((val_data_x.shape[1], val_data_x.shape[0]))
)
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %%
train_data_x[:10]
# Out:
# array([[-0.33200567,  1.96548088, -0.01930303, ..., -1.69449348,
#          0.99646721, -0.6939948 ],
#        [-0.47191037,  2.30021254,  0.07863308, ..., -1.2805858 ,
#          0.80844603, -0.27532169],
#        [-0.77869708,  2.21339278,  0.62488909, ..., -0.65125255,
#          0.1553411 ,  0.29267968],
#        ...,
#        [ 1.65250711,  0.82072275, -0.01995893, ..., -0.12922737,
#          0.11451315, -0.95260493],
#        [ 0.68307808,  0.87433598, -1.55161711, ..., -0.24645114,
#         -0.52567043, -0.7575487 ],
#        [-0.34263752,  1.06792256, -2.68225826, ..., -0.88113011,
#         -1.45606541, -0.60993698]], shape=(10, 4000))

# %% [markdown]
# Define the network

# %%
import torch.nn.functional as F

# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class


class ResidualNetwork(torch.nn.Module):
    def __init__(self, input_size, output_size, hidden_size=100):
        super(ResidualNetwork, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, hidden_size)
        self.linear4 = nn.Linear(hidden_size, hidden_size)
        self.linear5 = nn.Linear(hidden_size, hidden_size)
        self.linear6 = nn.Linear(hidden_size, output_size)
        print(
            "Initialized MLPBase model with {} parameters".format(self.count_params())
        )

    def count_params(self):
        return sum([p.view(-1).shape[0] for p in self.parameters()])

    # TODO -- Add residual connections to this model
    # The order of operations within each block should similar to figure 11.5b
    # ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
    # Replace this function
    # def forward(self, x):
    #     residual=x
    #
    #     h1 = self.linear1(x)
    #     h2 = h1+self.linear2(h1).relu()
    #
    #     #h1 = h1.relu()
    #     h3 =F.relu(x)+self.linear2(h2)
    #     h4 = self.linear3(h3).relu()
    #
    #     out=self.linear4(h4)
    #
    #     return out

    def forward(self, x):
        f = self.linear1(x)
        h1 = f + self.linear2(f.relu())
        h2 = h1 + self.linear3(h1.relu())
        return self.linear4(h2)

    # def forward(self,x):
    #     f = self.linear1(x)
    #     h1 = f + self.linear2(f.relu())
    #     h2 = h1+self.linear3(h1.relu())
    #     h3= h2+self.linear4(h2.relu())
    #     h4= h3+self.linear5(h3.relu())
    #
    #     return self.linear6(h4)

# %%
model = ResidualNetwork(40, 10)
model
# Out:
# Initialized MLPBase model with 45510 parameters
# ResidualNetwork(
#   (linear1): Linear(in_features=40, out_features=100, bias=True)
#   (linear2): Linear(in_features=100, out_features=100, bias=True)
#   (linear3): Linear(in_features=100, out_features=100, bias=True)
#   (linear4): Linear(in_features=100, out_features=100, bias=True)
#   (linear5): Linear(in_features=100, out_features=100, bias=True)
#   (linear6): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# He initialization of weights
def weights_init(layer_in):
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_uniform_(layer_in.weight)
        layer_in.bias.data.fill_(0.0)

# %%
# Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype("float32"))
y_train = torch.tensor(train_data_y.astype("long"))
x_val = torch.tensor(val_data_x.transpose().astype("float32"))
y_val = torch.tensor(val_data_y.astype("long"))

# load the data into a class that creates the batches
data_loader = DataLoader(
    TensorDataset(x_train, y_train),
    batch_size=100,
    shuffle=True,
    worker_init_fn=np.random.seed(1),
)

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
    # loop over batches
    for i, data in enumerate(data_loader):
        # retrieve inputs and labels for this batch
        x_batch, y_batch = data
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward pass -- calculate model output
        pred = model(x_batch)
        # compute the loss
        loss = loss_function(pred, y_batch)
        # backward pass
        loss.backward()
        # SGD update
        optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_val = model(x_val)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_val_class = torch.max(pred_val.data, 1)
    errors_train[epoch] = 100 - 100 * (
        predicted_train_class == y_train
    ).float().sum() / len(y_train)
    errors_val[epoch] = 100 - 100 * (predicted_val_class == y_val).float().sum() / len(
        y_val
    )
    losses_train[epoch] = loss_function(pred_train, y_train).item()
    losses_val[epoch] = loss_function(pred_val, y_val).item()
    print(
        f"Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}"
    )

    # tell scheduler to consider updating learning rate
    scheduler.step()
# Out:
# Initialized MLPBase model with 45510 parameters
# Epoch     0, train loss 1.667404, train error 61.70,  val loss 1.800367, percent error 66.60
# Epoch     1, train loss 1.165393, train error 43.90,  val loss 1.353765, percent error 51.50
# Epoch     2, train loss 1.023623, train error 37.75,  val loss 1.244146, percent error 49.20
# Epoch     3, train loss 0.933028, train error 34.85,  val loss 1.236112, percent error 47.00
# Epoch     4, train loss 0.822908, train error 31.78,  val loss 1.192601, percent error 45.50
# Epoch     5, train loss 0.732115, train error 28.05,  val loss 1.118050, percent error 40.80
# Epoch     6, train loss 0.714405, train error 26.18,  val loss 1.209503, percent error 42.10
# Epoch     7, train loss 0.626998, train error 23.25,  val loss 1.141585, percent error 39.90
# Epoch     8, train loss 0.604724, train error 23.10,  val loss 1.198377, percent error 39.90
# Epoch     9, train loss 0.589669, train error 22.18,  val loss 1.217360, percent error 38.90
# Epoch    10, train loss 0.495002, train error 17.97,  val loss 1.197128, percent error 38.40
# Epoch    11, train loss 0.490377, train error 18.28,  val loss 1.231841, percent error 37.30
# Epoch    12, train loss 0.458690, train error 17.53,  val loss 1.261377, percent error 38.00
# Epoch    13, train loss 0.386179, train error 14.07,  val loss 1.292076, percent error 38.90
# Epoch    14, train loss 0.456824, train error 16.57,  val loss 1.447321, percent error 38.60
# Epoch    15, train loss 0.388399, train error 14.07,  val loss 1.502121, percent error 39.40
# Epoch    16, train loss 0.344270, train error 12.97,  val loss 1.487953, percent error 37.30
# Epoch    17, train loss 0.402542, train error 14.53,  val loss 1.684480, percent error 39.40
# Epoch    18, train loss 0.331762, train error 12.00,  val loss 1.546910, percent error 36.30
# Epoch    19, train loss 0.311292, train error 11.18,  val loss 1.581917, percent error 36.20
# Epoch    20, train loss 0.095505, train error 2.60,  val loss 1.309162, percent error 32.30
# Epoch    21, train loss 0.049094, train error 0.68,  val loss 1.289349, percent error 32.20
# Epoch    22, train loss 0.030196, train error 0.25,  val loss 1.334223, percent error 32.60
# Epoch    23, train loss 0.020203, train error 0.05,  val loss 1.368581, percent error 32.00
# Epoch    24, train loss 0.015009, train error 0.00,  val loss 1.393836, percent error 31.80
# Epoch    25, train loss 0.012586, train error 0.00,  val loss 1.432715, percent error 31.80
# Epoch    26, train loss 0.010625, train error 0.00,  val loss 1.456280, percent error 31.80
# Epoch    27, train loss 0.009279, train error 0.00,  val loss 1.475355, percent error 31.50
# Epoch    28, train loss 0.008282, train error 0.00,  val loss 1.502549, percent error 32.10
# Epoch    29, train loss 0.007489, train error 0.00,  val loss 1.517768, percent error 31.90
# Epoch    30, train loss 0.006801, train error 0.00,  val loss 1.544356, percent error 32.10
# Epoch    31, train loss 0.006253, train error 0.00,  val loss 1.555780, percent error 32.20
# Epoch    32, train loss 0.005757, train error 0.00,  val loss 1.572557, percent error 31.90
# Epoch    33, train loss 0.005328, train error 0.00,  val loss 1.586768, percent error 32.50
# Epoch    34, train loss 0.004999, train error 0.00,  val loss 1.597846, percent error 31.90
# Epoch    35, train loss 0.004678, train error 0.00,  val loss 1.617410, percent error 32.60
# Epoch    36, train loss 0.004397, train error 0.00,  val loss 1.624848, percent error 32.20
# Epoch    37, train loss 0.004138, train error 0.00,  val loss 1.641644, percent error 32.40
# Epoch    38, train loss 0.003925, train error 0.00,  val loss 1.650345, percent error 32.50
# Epoch    39, train loss 0.003717, train error 0.00,  val loss 1.660232, percent error 32.60
# Epoch    40, train loss 0.003623, train error 0.00,  val loss 1.665552, percent error 32.60
# Epoch    41, train loss 0.003536, train error 0.00,  val loss 1.671499, percent error 32.30
# Epoch    42, train loss 0.003453, train error 0.00,  val loss 1.677699, percent error 32.60
# Epoch    43, train loss 0.003374, train error 0.00,  val loss 1.683056, percent error 32.30
# Epoch    44, train loss 0.003300, train error 0.00,  val loss 1.687191, percent error 32.40
# Epoch    45, train loss 0.003227, train error 0.00,  val loss 1.692258, percent error 32.30
# Epoch    46, train loss 0.003158, train error 0.00,  val loss 1.697168, percent error 32.30
# Epoch    47, train loss 0.003092, train error 0.00,  val loss 1.701362, percent error 32.30
# Epoch    48, train loss 0.003029, train error 0.00,  val loss 1.706400, percent error 32.20
# Epoch    49, train loss 0.002967, train error 0.00,  val loss 1.710409, percent error 32.30
# Epoch    50, train loss 0.002907, train error 0.00,  val loss 1.716634, percent error 32.20
# Epoch    51, train loss 0.002851, train error 0.00,  val loss 1.719859, percent error 32.30
# Epoch    52, train loss 0.002796, train error 0.00,  val loss 1.723195, percent error 32.20
# Epoch    53, train loss 0.002742, train error 0.00,  val loss 1.728279, percent error 32.20
# Epoch    54, train loss 0.002692, train error 0.00,  val loss 1.733417, percent error 32.30
# Epoch    55, train loss 0.002641, train error 0.00,  val loss 1.736190, percent error 32.20
# Epoch    56, train loss 0.002594, train error 0.00,  val loss 1.740752, percent error 32.30
# Epoch    57, train loss 0.002547, train error 0.00,  val loss 1.744235, percent error 32.20
# Epoch    58, train loss 0.002503, train error 0.00,  val loss 1.749021, percent error 32.30
# Epoch    59, train loss 0.002461, train error 0.00,  val loss 1.751363, percent error 32.30
# Epoch    60, train loss 0.002438, train error 0.00,  val loss 1.754350, percent error 32.30
# Epoch    61, train loss 0.002417, train error 0.00,  val loss 1.756155, percent error 32.30
# Epoch    62, train loss 0.002397, train error 0.00,  val loss 1.758241, percent error 32.30
# Epoch    63, train loss 0.002377, train error 0.00,  val loss 1.759798, percent error 32.30
# Epoch    64, train loss 0.002357, train error 0.00,  val loss 1.761554, percent error 32.20
# Epoch    65, train loss 0.002338, train error 0.00,  val loss 1.763851, percent error 32.30
# Epoch    66, train loss 0.002319, train error 0.00,  val loss 1.765305, percent error 32.30
# Epoch    67, train loss 0.002300, train error 0.00,  val loss 1.767459, percent error 32.30
# Epoch    68, train loss 0.002281, train error 0.00,  val loss 1.768677, percent error 32.20
# Epoch    69, train loss 0.002263, train error 0.00,  val loss 1.770291, percent error 32.30
# Epoch    70, train loss 0.002245, train error 0.00,  val loss 1.772395, percent error 32.30
# Epoch    71, train loss 0.002227, train error 0.00,  val loss 1.774518, percent error 32.30
# Epoch    72, train loss 0.002210, train error 0.00,  val loss 1.776239, percent error 32.30
# Epoch    73, train loss 0.002193, train error 0.00,  val loss 1.778208, percent error 32.40
# Epoch    74, train loss 0.002176, train error 0.00,  val loss 1.779638, percent error 32.30
# Epoch    75, train loss 0.002160, train error 0.00,  val loss 1.780871, percent error 32.30
# Epoch    76, train loss 0.002143, train error 0.00,  val loss 1.783067, percent error 32.30
# Epoch    77, train loss 0.002127, train error 0.00,  val loss 1.784479, percent error 32.40
# Epoch    78, train loss 0.002111, train error 0.00,  val loss 1.786098, percent error 32.40
# Epoch    79, train loss 0.002096, train error 0.00,  val loss 1.788009, percent error 32.40
# Epoch    80, train loss 0.002088, train error 0.00,  val loss 1.788911, percent error 32.40
# Epoch    81, train loss 0.002080, train error 0.00,  val loss 1.789671, percent error 32.30
# Epoch    82, train loss 0.002072, train error 0.00,  val loss 1.790416, percent error 32.30
# Epoch    83, train loss 0.002065, train error 0.00,  val loss 1.791344, percent error 32.30
# Epoch    84, train loss 0.002057, train error 0.00,  val loss 1.792198, percent error 32.40
# Epoch    85, train loss 0.002050, train error 0.00,  val loss 1.793133, percent error 32.40
# Epoch    86, train loss 0.002042, train error 0.00,  val loss 1.793593, percent error 32.40
# Epoch    87, train loss 0.002035, train error 0.00,  val loss 1.794659, percent error 32.40
# Epoch    88, train loss 0.002028, train error 0.00,  val loss 1.795607, percent error 32.30
# Epoch    89, train loss 0.002020, train error 0.00,  val loss 1.796219, percent error 32.30
# Epoch    90, train loss 0.002013, train error 0.00,  val loss 1.797108, percent error 32.30
# Epoch    91, train loss 0.002006, train error 0.00,  val loss 1.797849, percent error 32.30
# Epoch    92, train loss 0.001999, train error 0.00,  val loss 1.798676, percent error 32.30
# Epoch    93, train loss 0.001992, train error 0.00,  val loss 1.799642, percent error 32.40
# Epoch    94, train loss 0.001985, train error 0.00,  val loss 1.800139, percent error 32.30
# Epoch    95, train loss 0.001978, train error 0.00,  val loss 1.801187, percent error 32.30
# Epoch    96, train loss 0.001971, train error 0.00,  val loss 1.802016, percent error 32.30
# Epoch    97, train loss 0.001964, train error 0.00,  val loss 1.802681, percent error 32.30
# Epoch    98, train loss 0.001957, train error 0.00,  val loss 1.803367, percent error 32.30
# Epoch    99, train loss 0.001950, train error 0.00,  val loss 1.803982, percent error 32.30

# %%
torch.save(model, "With_Residual_6_layers.pt")

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train, "r-", label="train")
ax.plot(errors_val, "b-", label="test")
ax.set_ylim(0, 100)
ax.set_xlim(0, n_epoch)
ax.set_xlabel("Epoch")
ax.set_ylabel("Error")
ax.set_title("TrainError %3.2f, Val Error %3.2f" % (errors_train[-1], errors_val[-1]))
ax.legend()
plt.savefig("With_Residual.png")
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
