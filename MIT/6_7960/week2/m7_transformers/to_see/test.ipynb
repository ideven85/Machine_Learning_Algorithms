# %%
# !pip install nltk
# !pip install keras
# !pip install gensim
# !pip install seaborn

# %%
import nltk

nltk.download("brown")
nltk.download("treebank")
nltk.download("conll2000")
nltk.download("punkt")
nltk.download("universal_tagset")
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\ak007\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\ak007\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\ak007\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\conll2000.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ak007\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\ak007\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\universal_tagset.zip.
# True

# %%
# !pip install tensorflow intel-extension-for-tensorflow
# Out:
# ...
#   Using cached intel_extension_for_tensorflow-0.0.0.dev1-py3-none-any.whl.metadata (2.1 kB)
# ...
# Using cached intel_extension_for_tensorflow-0.0.0.dev1-py3-none-any.whl (3.7 kB)
# ...

# %%
import tensorflow as tf

# %%
w1 = tf.Variable([[-1], [1], [-1.2]])
b = tf.Variable([0.01])
X = tf.Variable([[0.2], [1], [0.5]])
w1 = tf.transpose(w1)
a = w1 @ X
a + b
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[5], line 5
#       3 X = tf.Variable([[0.2], [1], [0.5]])
#       4 w1 = tf.transpose(w1)
# ----> 5 w1 = tf.linalg.inv(w1)
#       6 a = w1 @ X
#       7 a + b
#
# File ~\anaconda4\Lib\site-packages\tensorflow\python\ops\gen_linalg_ops.py:1549, in matrix_inverse(input, adjoint, name)
#    1547   return _result
#    1548 except _core._NotOkStatusException as e:
# -> 1549   _ops.raise_from_not_ok_status(e, name)
#    1550 except _core._FallbackException:
#    1551   pass
#
# File ~\anaconda4\Lib\site-packages\tensorflow\python\framework\ops.py:6027, in raise_from_not_ok_status(e, name)
#    6025 def raise_from_not_ok_status(e, name) -> NoReturn:
#    6026   e.message += (" name: " + str(name if name is not None else ""))
# -> 6027   raise core._status_to_exception(e) from None
#
# ...
