# %%
import torch

# %%
X = torch.tensor([[1,0,1],[1,0,1]])
Y = torch.tensor([6])

# %%
(torch.transpose(X)*Y)*torch.linalg.inv(X@Y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 (torch.transpose(X)*Y)*torch.linalg.inv(X@Y)
#
# TypeError: transpose() received an invalid combination of arguments - got (Tensor), but expected one of:
#  * (Tensor input, int dim0, int dim1)
#  * (Tensor input, name dim0, name dim1)

# %%
num=(X.T@Y)

# %%
X.T*Y
# Out:
# tensor([18])

# %%
import numpy as np
np.linalg.inv(np.transpose(X)
# Out:
# tensor(18)
