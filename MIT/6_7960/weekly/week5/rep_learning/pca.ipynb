# %%
import numpy as np

# %%
a = np.array([[1 / 3, 1 / 3], [-1 / 3, 2 / 3]], dtype=np.float32)
b = np.array([[2, -1], [1, 1]], dtype=np.float32)

# %%
a @ b
# Out:
# array([[1., 0.],
#        [0., 1.]], dtype=float32)

# %%
import torch

A = torch.tensor(a)
B = torch.tensor(b)

# %%
A @ B
# Out:
# tensor([[1., 0.],
#         [0., 1.]])

# %%
A.dtype
# Out:
# torch.float64

# %%
B.dtype
# Out:
# torch.int64

# %%
B.inverse()
# Out:
# tensor([[ 0.3333,  0.3333],
#         [-0.3333,  0.6667]])
