# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/data1_train.csv", sep=" ", header=None)

# %%
df
# Out:
#             0         1    2
# 0   -1.389960  1.793067  1.0
# 1    1.902475  2.604644  1.0
# 2    2.055110  2.104022  1.0
# 3    2.061958  2.319986  1.0
# 4    1.994181  1.790267  1.0
# ..        ...       ...  ...
# 395  1.947352  2.178258  1.0
# 396 -1.728638  1.943001  1.0
# 397  1.916037  2.866981  1.0
# 398 -1.975005 -2.004443 -1.0
# 399 -1.935368 -2.018332 -1.0
#
# [400 rows x 3 columns]

# %%
df.to_csv("data/sample.csv")
