# %%
# Reading the file using open()
file = open("Shakespeare_data.csv", mode="r", encoding="utf-8")

# Getting text data as string
text = file.read()

# Closing the file
file.close()

# %%
lines = text.split("\n")

# %%
for i in range(10):
    # print(lines[i])
    line = lines[i].split(",")
    print(line[5])
# Out:
# "PlayerLine"
# "ACT I"
# "SCENE I. London. The palace."
# "Enter KING HENRY
# "So shaken as we are
# "Find we a time for frighted peace to pant
# "And breathe short-winded accents of new broils"
# "To be commenced in strands afar remote."
# "No more the thirsty entrance of this soil"
# "Shall daub her lips with her own children's blood

# %%
import re

sentences = []
for line in lines:
    # get only the playerline
    l = line.split(",")

    if len(l) >= 5:
        l = l[5]

        # remove punctuation
        line = re.sub(r'[\!"#$%&\*+,-./:;<=>?@^_`()|~=]', "", l).strip()

        # tokenizer
        tokens = re.findall(r"\b\w+\b", line)

        if len(tokens) > 1:
            sentences.append(tokens)

# %%
for i in range(10):
    print(sentences[i])
# Out:
# ['ACT', 'I']
# ['SCENE', 'I', 'London', 'The', 'palace']
# ['Enter', 'KING', 'HENRY']
# ['So', 'shaken', 'as', 'we', 'are']
# ['Find', 'we', 'a', 'time', 'for', 'frighted', 'peace', 'to', 'pant']
# ['And', 'breathe', 'shortwinded', 'accents', 'of', 'new', 'broils']
# ['To', 'be', 'commenced', 'in', 'strands', 'afar', 'remote']
# ['No', 'more', 'the', 'thirsty', 'entrance', 'of', 'this', 'soil']
# ['Shall', 'daub', 'her', 'lips', 'with', 'her', 'own', 'children', 's', 'blood']
# ['Nor', 'more', 'shall', 'trenching', 'war', 'channel', 'her', 'fields']

# %%
# This is cbow implementation
# remember in Word2Vec we convert the text into a vector of real numbers.
# dimensionality is the length of the vector.
# More information - https://stackoverflow.com/questions/45394949/what-is-dimensionality-in-word-embeddings

# More information on below - https://radimrehurek.com/gensim/models/word2vec.html

from gensim.models import Word2Vec

shakes2Vec_cbow = Word2Vec(
    sentences,
    min_count=3,  # Ignore words that appear less than this
    # size=50,       # Dimensionality of word embeddings - length of the the vectors
    sg=0,  # binary true or false - if sg is 0, it would pick up cbow,
    window=7,
)  # Context window for words during training
# iter=40)       # Number of epochs training over corpus

# %%
shakes2Vec_cbow.wv.most_similar("husband")
# Out:
# [('brother', 0.976158857345581),
#  ('master', 0.9643411636352539),
#  ('daughter', 0.964337944984436),
#  ('mother', 0.963929295539856),
#  ('wife', 0.9617480635643005),
#  ('father', 0.9592041373252869),
#  ('tongue', 0.9503167271614075),
#  ('friend', 0.9501005411148071),
#  ('son', 0.9464338421821594),
#  ('mind', 0.9424840211868286)]

# %%
help(Word2Vec)
# Out:
# Help on class Word2Vec in module gensim.models.word2vec:
#
# class Word2Vec(gensim.utils.SaveLoad)
#  |  Word2Vec(sentences=None, corpus_file=None, vector_size=100, alpha=0.025, window=5, min_count=5, max_vocab_size=None, sample=0.001, seed=1, workers=3, min_alpha=0.0001, sg=0, hs=0, negative=5, ns_exponent=0.75, cbow_mean=1, hashfxn=<built-in function hash>, epochs=5, null_word=0, trim_rule=None, sorted_vocab=1, batch_words=10000, compute_loss=False, callbacks=(), comment=None, max_final_vocab=None, shrink_windows=True)
#  |
#  |  Method resolution order:
#  |      Word2Vec
#  |      gensim.utils.SaveLoad
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
# ...

# %%
# This is skip gram implementation ------ sg  1

# remember in Word2Vec we convert the text into a vector of real numbers.
# dimensionality is the length of the vector.
# More information - https://stackoverflow.com/questions/45394949/what-is-dimensionality-in-word-embeddings

from gensim.models import Word2Vec

shakes2Vec_sg = Word2Vec(
    sentences,
    min_count=3,  # Ignore words that appear less than this
    vector_size=50,  # Dimensionality of word embeddings - length of the the vectors
    sg=1,  # skipgrams
    window=7,  # Context window for words during training
    epochs=40,
)  # Number of epochs training over corpus

# %%
shakes2Vec_sg.wv.most_similar("husband")
# Out:
# [('wife', 0.771894633769989),
#  ('sister', 0.7571795582771301),
#  ('father', 0.7390968203544617),
#  ('master', 0.7279189229011536),
#  ('daughter', 0.7223402261734009),
#  ('lady', 0.7198172807693481),
#  ('mistress', 0.7161113023757935),
#  ('boy', 0.7066671252250671),
#  ('son', 0.7064552307128906),
#  ('Slender', 0.691272497177124)]

# %% [markdown]
# ### End words
#
# So which one think did better? CBOW or Skipgrams?
#
# ----------------------------------------------
# #### How to evaluate?
#
# There are two ways.
#
# #### Intrinsic evaluation
# involves comparing the embedding to a reference model. For example, comparing word similarity to an existing lexical database, such as WordNet. One can also manually annotate the embedding process results (not advisable, takes time and human resources, but if available great)
#
# #### Extrinsic evaluation
# consists of evaluating the model's performance with regards to a downstream task such as text classification, machine translation, or summarization. The downstream task has its own performance evaluation strategy, which gives you insight into the embedding model's accuracy.
#
#
# ----------------------------------------------
#
#
# You should not face a situation to create your own vectors file, as such trained output on wikipedia or google is made available from the internet and you can directly use them. I would use one such trained vectors to do sentiment analysis on Twitter dataset.
#
# I have gone through the video of the lectures. And they are one of the best presentation on the logic I have ever seen. I was always in awe of the NLP courses at IIIT Hyderabad.
#
# If you have doubts, do reach out to me on concepts.
